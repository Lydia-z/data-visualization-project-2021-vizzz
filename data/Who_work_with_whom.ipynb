# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./full_data.csv', error_bad_lines=False)
print('size of the third dataset is ', data.shape)
data.head()
# Out:
# size of the third dataset is  (224, 14)
#    Unnamed: 0            title  Running time     Budget   Box office  \
# 0           0        Pinocchio          88.0  2600000.0  164000000.0
# 1           1         Fantasia         126.0  2280000.0   83300000.0
# 2           2            Dumbo          64.0   950000.0    1300000.0
# 3           3            Bambi          70.0   858000.0  267400000.0
# 4           4  Make Mine Music          75.0  1350000.0    3275000.0
#
#   Release date  imdb  metascore  rotten_tomatoes  \
# 0   1940-02-07   7.4       99.0              100
# 1   1940-11-13   7.8       96.0               95
# 2   1941-10-23   7.2       96.0               98
# 3   1942-08-09   7.3       91.0               90
# 4   1946-04-20   6.3       60.0               70
#
#                                          Directed by  \
# 0  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 1  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 2  ['Supervising director:', 'Ben Sharpsteen', 'S...
# 3  ['Supervising director', 'David Hand', 'Sequen...
# 4  ['Jack Kinney', 'Clyde Geronimi', 'Hamilton Lu...
#
#                          Produced by  \
# 0                        Walt Disney
# 1  ['Walt Disney', 'Ben Sharpsteen']
# 2                        Walt Disney
# 3                        Walt Disney
# 4                        Walt Disney
#
#                                             Music by  \
# 0                 ['Leigh Harline', 'Paul J. Smith']
# 1                                        See program
# 2              ['Frank Churchill', 'Oliver Wallace']
# 3             ['Frank Churchill', 'Edward H. Plumb']
# 4  ['Eliot Daniel', 'Ken Darby', 'Charles Wolcott...
#
#                                       Distributed by  year
# 0                                 RKO Radio Pictures  1940
# 1  ['Walt Disney Productions', 'RKO Radio Pictures']  1940
# 2                                 RKO Radio Pictures  1941
# 3                                 RKO Radio Pictures  1942
# 4                           RKO Radio Pictures, Inc.  1946

# %%
directors ={} #{name: count}
producers = {}
music_directors = {}

directors_edges = [] #[(source, target)...]
producers_edges = []
music_directors_edges = []

# %%
def get_nodes_edges(string, nodes, links):
    if(string == 'nan'):
        return nodes, links
    # if the string is with []
    #print(string)
    if('[' in string and ']' in string):
        # get rid of the []
        string = string[1:-1]
        
    names = sorted(string.split(', '))
    for name in names:
        # if name string with ''
        if('\'' in name):
            name = name[1:-1]
        # get rid of '(' or ')' or '(blahblahblah)' as they are all explaination
        if(name.startswith('(')):
            continue
        if(name.startswith(')')):
            continue
            
        if name in nodes:
            nodes[name] += 1
        else:
            nodes[name] = 1
    
    for i in range(len(names)):
        # if name string with ''
        if('\'' in names[i]):
            names[i] = names[i][1:-1]
        # get rid of '(' or ')' or '(blahblahblah)' as they are all explaination
        if(names[i].startswith('(')):
            continue
        if(names[i].startswith(')')):
            continue
            
        for j in range(i+1, len(names)):
            # if name string with ''
            if('\'' in names[j]):
                names[j] = names[j][1:-1]
                # get rid of '(' or ')' or '(blahblahblah)' as they are all explaination
            if(names[j].startswith('(')):
                continue
            if(names[j].startswith(')')):
                continue
            links.append((names[i],names[j]))
            
    return nodes, links

# %%
for ind, row in data.iterrows():
    if(pd.notna(row['Directed by'])):
        directors,directors_edges = get_nodes_edges(row['Directed by'],directors,directors_edges)
    if(pd.notna(row['Produced by'])):
        producers,producers_edges = get_nodes_edges(row['Produced by'],producers,producers_edges)
    if(pd.notna(row['Music by'])):
        music_directors,music_directors_edges = get_nodes_edges(row['Music by'],music_directors,music_directors_edges)

# %%
import collections
counter=collections.Counter(directors_edges)

# %%
director_nodes = [{"name":key,"count":directors[key]} for key in directors]

# %%
director_nodes
# Out:
# [{'name': 'Ben Sharpsteen', 'count': 3},
#  {'name': 'Bill Roberts', 'count': 4},
#  {'name': 'Hamilton Luske', 'count': 9},
#  {'name': 'Jack Kinney', 'count': 4},
#  {'name': 'Norman Ferguson', 'count': 3},
#  {'name': 'T. Hee', 'count': 2},
#  {'name': 'Wilfred Jackson', 'count': 9},
#  {'name': 'David D. Hand', 'count': 1},
#  {'name': 'Ford Beebe', 'count': 1},
#  {'name': 'James Algar', 'count': 5},
#  {'name': 'Jim Handley', 'count': 1},
#  {'name': 'Paul Satterfield', 'count': 2},
#  {'name': 'Samuel Armstrong', 'count': 3},
#  {'name': 'Sequence directors:', 'count': 1},
#  {'name': 'Supervising director:', 'count': 1},
#  {'name': 'David Hand', 'count': 1},
#  {'name': 'Graham Heid', 'count': 1},
#  {'name': 'Norman Wright', 'count': 1},
#  {'name': 'Sequence directors', 'count': 1},
#  {'name': 'Supervising director', 'count': 1},
#  {'name': 'Clyde Geronimi', 'count': 7},
#  {'name': 'Joshua Meador', 'count': 1},
#  {'name': 'Robert Cormack', 'count': 1},
#  {'name': 'Animation:', 'count': 1},
#  {'name': 'Harve Foster', 'count': 1},
#  {'name': 'Live action:', 'count': 1},
#  {'name': 'Richard Fleischer', 'count': 1},
#  {'name': 'Clyde Geronimi (supervising)', 'count': 1},
#  {'name': 'Eric Larson', 'count': 1},
#  {'name': 'Les Clark', 'count': 1},
#  {'name': 'Wolfgang Reitherman', 'count': 7},
#  {'name': 'Charles Barton', 'count': 1},
#  {'name': 'John McKimson', 'count': 1},
#  {'name': 'Ken Annakin', 'count': 1},
#  {'name': 'Jack Donohue', 'count': 1},
#  {'name': 'Robert Stevenson', 'count': 3},
#  {'name': 'Gary Nelson', 'count': 3},
#  {'name': 'Art Stevens', 'count': 2},
#  {'name': 'John Lounsbery', 'count': 1},
#  {'name': 'Don Chaffey', 'count': 1},
#  {'name': 'Robert Altman', 'count': 1},
#  {'name': 'Matthew Robbins', 'count': 1},
#  {'name': 'Richard Rich', 'count': 2},
#  {'name': 'Ted Berman', 'count': 2},
#  {'name': 'Tim Hunter', 'count': 1},
#  {'name': 'Walter Murch', 'count': 1},
#  {'name': 'Burny Mattinson', 'count': 1},
#  {'name': 'Dave Michener', 'count': 1},
#  {'name': 'John Musker', 'count': 6},
#  {'name': 'Ron Clements', 'count': 6},
#  {'name': 'Randal Kleiser', 'count': 3},
#  {'name': 'George Scribner', 'count': 1},
#  {'name': 'Joe Johnston', 'count': 3},
#  {'name': 'Gary Trousdale', 'count': 3},
#  {'name': 'Kirk Wise', 'count': 3},
#  {'name': 'Kenny Ortega', 'count': 1},
#  {'name': 'Stephen Herek', 'count': 3},
#  {'name': 'Brian Henson', 'count': 2},
#  {'name': 'Jon Turteltaub', 'count': 4},
#  {'name': 'Henry Selick', 'count': 2},
#  {'name': 'Rupert Wainwright', 'count': 1},
#  {'name': 'Rob Minkoff', 'count': 2},
#  {'name': 'Roger Allers', 'count': 1},
#  {'name': 'William Dear', 'count': 1},
#  {'name': 'John Pasquin', 'count': 2},
#  {'name': 'James Orr', 'count': 1},
#  {'name': 'Eric Goldberg', 'count': 3},
#  {'name': 'Mike Gabriel', 'count': 1},
#  {'name': 'Simon Wincer', 'count': 1},
#  {'name': 'Michael Gottlieb', 'count': 1},
#  {'name': 'John Lasseter', 'count': 5},
#  {'name': 'David M. Evans', 'count': 1},
#  {'name': 'Sam Weisman', 'count': 1},
#  {'name': 'Les Mayfield', 'count': 1},
#  {'name': 'Stanley Tong', 'count': 1},
#  {'name': 'Barry Cook', 'count': 1},
#  {'name': 'Tony Bancroft', 'count': 1},
#  {'name': 'Nancy Meyers', 'count': 1},
#  {'name': 'Ron Underwood', 'count': 1},
#  {'name': 'Donald Petrie', 'count': 1},
#  {'name': 'Chris Buck', 'count': 3},
#  {'name': 'Kevin Lima', 'count': 3},
#  {'name': 'David Kellogg', 'count': 1},
#  {'name': 'Don Hahn', 'count': 2},
#  {'name': 'Francis Glebas', 'count': 3},
#  {'name': 'Hendel Butoy', 'count': 2},
#  {'name': 'Paul and Gaëtan Brizzi', 'count': 2},
#  {'name': 'Pixote Hunt', 'count': 2},
#  {'name': 'Jun Falkenstein', 'count': 1},
#  {'name': 'Eric Leighton', 'count': 1},
#  {'name': 'Ralph Zondag', 'count': 1},
#  {'name': 'Boaz Yakin', 'count': 1},
#  {'name': 'Mark Dindal', 'count': 2},
#  {'name': 'Chuck Sheetz', 'count': 1},
#  {'name': 'Garry Marshall', 'count': 2},
#  {'name': 'Tim Hill', 'count': 1},
#  {'name': 'Pete Docter', 'count': 3},
#  {'name': 'Brian Levant', 'count': 1},
#  {'name': 'Robin Budd', 'count': 1},
#  {'name': 'John Lee Hancock', 'count': 2},
#  {'name': 'Chris Sanders', 'count': 1},
#  {'name': 'Dean DeBlois', 'count': 1},
#  {'name': 'Peter Hastings', 'count': 1},
#  {'name': 'Jay Russell', 'count': 1},
#  {'name': 'Michael Lembeck', 'count': 2},
#  {'name': 'Steve Trenbirth', 'count': 1},
#  {'name': 'James Cameron', 'count': 1},
#  {'name': 'Andrew Davis', 'count': 1},
#  {'name': 'Jim Fall', 'count': 1},
#  {'name': 'Andrew Stanton', 'count': 4},
#  {'name': 'Gore Verbinski', 'count': 4},
#  {'name': 'Mark Waters', 'count': 1},
#  {'name': 'Aaron Blaise', 'count': 1},
#  {'name': 'Robert Walker', 'count': 1},
#  {'name': "avin O'Conno", 'count': 1},
#  {'name': 'Sara Sugarman', 'count': 1},
#  {'name': 'John Sanford', 'count': 1},
#  {'name': 'Will Finn', 'count': 1},
#  {'name': 'Frank Coraci', 'count': 1},
#  {'name': 'Luc Jacquet', 'count': 1},
#  {'name': 'Frank Nissen', 'count': 1},
#  {'name': 'Adam Shankman', 'count': 2},
#  {'name': 'Tim Fywell', 'count': 1},
#  {'name': 'Gary Chapman', 'count': 1},
#  {'name': 'Angela Robinson', 'count': 1},
#  {'name': 'Mike Mitchell', 'count': 1},
#  {'name': 'Bill Paxton', 'count': 1},
#  {'name': 'Andrew Adamson', 'count': 2},
#  {'name': 'James Gartner', 'count': 1},
#  {'name': 'George Butler', 'count': 1},
#  {'name': 'Frank Marshall', 'count': 1},
#  {'name': 'Brian Robbins', 'count': 1},
#  {'name': 'Steve "Spaz" Williams', 'count': 1},
#  {'name': 'Ericson Core', 'count': 1},
#  {'name': 'Gábor Csupó', 'count': 1},
#  {'name': 'Brad Bird', 'count': 3},
#  {'name': 'Frederik Du Chau', 'count': 1},
#  {'name': 'Andy Fickman', 'count': 2},
#  {'name': 'Alastair Fothergill', 'count': 5},
#  {'name': 'Mark Linfield', 'count': 3},
#  {'name': 'Bruce Hendricks', 'count': 1},
#  {'name': 'Roger Kumble', 'count': 1},
#  {'name': 'Raja Gosnell', 'count': 2},
#  {'name': 'Byron Howard', 'count': 3},
#  {'name': 'Chris Williams', 'count': 2},
#  {'name': 'Peter Chelsom', 'count': 1},
#  {'name': 'Hoyt H. Yeatman Jr.', 'count': 1},
#  {'name': 'Jacques Cluzaud', 'count': 1},
#  {'name': 'Jacques Perrin', 'count': 1},
#  {'name': 'Robert Zemeckis', 'count': 1},
#  {'name': 'Walt Becker', 'count': 1},
#  {'name': 'Tim Burton', 'count': 3},
#  {'name': 'Mike Newell', 'count': 1},
#  {'name': 'Lee Unkrich', 'count': 2},
#  {'name': 'Hiromasa Yonebayashi', 'count': 1},
#  {'name': 'Randall Wallace', 'count': 1},
#  {'name': 'Nathan Greno', 'count': 1},
#  {'name': 'Joseph Kosinski', 'count': 1},
#  {'name': 'Simon Wells', 'count': 1},
#  {'name': 'Don Hall', 'count': 2},
#  {'name': 'Stephen J. Anderson', 'count': 1},
#  {'name': 'Keith Scholey', 'count': 2},
#  {'name': 'Joe Nussbaum', 'count': 1},
#  {'name': 'Rob Marshall', 'count': 3},
#  {'name': 'James Bobin', 'count': 3},
#  {'name': 'Brenda Chapman', 'count': 1},
#  {'name': 'Mark Andrews', 'count': 1},
#  {'name': 'Peter Hedges', 'count': 1},
#  {'name': 'Rich Moore', 'count': 3},
#  {'name': 'Sam Raimi', 'count': 1},
#  {'name': 'Dan Scanlon', 'count': 2},
#  {'name': 'Klay Hall', 'count': 1},
#  {'name': 'Jennifer Lee', 'count': 2},
#  {'name': 'Craig Gillespie', 'count': 2},
#  {'name': 'Robert Stromberg', 'count': 1},
#  {'name': 'Bobs Gannaway', 'count': 1},
#  {'name': 'Miguel Arteta', 'count': 1},
#  {'name': 'Niki Caro', 'count': 2},
#  {'name': 'Kenneth Branagh', 'count': 1},
#  {'name': 'Peter Sohn', 'count': 1},
#  {'name': 'Jon Favreau', 'count': 2},
#  {'name': 'Steven Spielberg', 'count': 1},
#  {'name': 'David Lowery', 'count': 1},
#  {'name': 'Lu Chuan', 'count': 1},
#  {'name': 'Mira Nair', 'count': 1},
#  {'name': 'Bill Condon', 'count': 1},
#  {'name': 'Espen Sandberg', 'count': 1},
#  {'name': 'Joachim Rønning', 'count': 2},
#  {'name': 'Brian Fee', 'count': 1},
#  {'name': 'Ava DuVernay', 'count': 1},
#  {'name': 'Lasse Hallström', 'count': 1},
#  {'name': 'Phil Johnston', 'count': 1},
#  {'name': 'Josh Cooley', 'count': 1}]

# %%
director_links = [{"source":key[0],"target":key[1],"weight":counter[key]} for key in counter]

# %%
director_links
# Out:
# [{'source': 'Ben Sharpsteen', 'target': 'Bill Roberts', 'weight': 3},
#  {'source': 'Ben Sharpsteen', 'target': 'Hamilton Luske', 'weight': 2},
#  {'source': 'Ben Sharpsteen', 'target': 'Jack Kinney', 'weight': 2},
#  {'source': 'Ben Sharpsteen', 'target': 'Norman Ferguson', 'weight': 3},
#  {'source': 'Ben Sharpsteen', 'target': 'T. Hee', 'weight': 2},
#  {'source': 'Ben Sharpsteen', 'target': 'Wilfred Jackson', 'weight': 3},
#  {'source': 'Bill Roberts', 'target': 'Hamilton Luske', 'weight': 2},
#  {'source': 'Bill Roberts', 'target': 'Jack Kinney', 'weight': 2},
#  {'source': 'Bill Roberts', 'target': 'Norman Ferguson', 'weight': 3},
#  {'source': 'Bill Roberts', 'target': 'T. Hee', 'weight': 2},
#  {'source': 'Bill Roberts', 'target': 'Wilfred Jackson', 'weight': 3},
#  {'source': 'Hamilton Luske', 'target': 'Jack Kinney', 'weight': 3},
#  {'source': 'Hamilton Luske', 'target': 'Norman Ferguson', 'weight': 2},
#  {'source': 'Hamilton Luske', 'target': 'T. Hee', 'weight': 2},
#  {'source': 'Hamilton Luske', 'target': 'Wilfred Jackson', 'weight': 7},
#  {'source': 'Jack Kinney', 'target': 'Norman Ferguson', 'weight': 2},
#  {'source': 'Jack Kinney', 'target': 'T. Hee', 'weight': 1},
#  {'source': 'Jack Kinney', 'target': 'Wilfred Jackson', 'weight': 3},
#  {'source': 'Norman Ferguson', 'target': 'T. Hee', 'weight': 2},
#  {'source': 'Norman Ferguson', 'target': 'Wilfred Jackson', 'weight': 3},
#  {'source': 'T. Hee', 'target': 'Wilfred Jackson', 'weight': 2},
#  {'source': 'Ben Sharpsteen', 'target': 'David D. Hand', 'weight': 1},
#  {'source': 'Ben Sharpsteen', 'target': 'Ford Beebe', 'weight': 1},
#  {'source': 'Ben Sharpsteen', 'target': 'James Algar', 'weight': 1},
#  {'source': 'Ben Sharpsteen', 'target': 'Jim Handley', 'weight': 1},
#  {'source': 'Ben Sharpsteen', 'target': 'Paul Satterfield', 'weight': 1},
#  {'source': 'Ben Sharpsteen', 'target': 'Samuel Armstrong', 'weight': 2},
#  {'source': 'Bill Roberts', 'target': 'David D. Hand', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'Ford Beebe', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'James Algar', 'weight': 2},
#  {'source': 'Bill Roberts', 'target': 'Jim Handley', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'Paul Satterfield', 'weight': 2},
#  {'source': 'Bill Roberts', 'target': 'Samuel Armstrong', 'weight': 3},
#  {'source': 'David D. Hand', 'target': 'Ford Beebe', 'weight': 1},
#  {'source': 'David D. Hand', 'target': 'Hamilton Luske', 'weight': 1},
#  {'source': 'David D. Hand', 'target': 'James Algar', 'weight': 1},
#  {'source': 'David D. Hand', 'target': 'Jim Handley', 'weight': 1},
#  {'source': 'David D. Hand', 'target': 'Norman Ferguson', 'weight': 1},
#  {'source': 'David D. Hand', 'target': 'Paul Satterfield', 'weight': 1},
#  {'source': 'David D. Hand', 'target': 'Samuel Armstrong', 'weight': 1},
#  {'source': 'David D. Hand', 'target': 'T. Hee', 'weight': 1},
#  {'source': 'David D. Hand', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Ford Beebe', 'target': 'Hamilton Luske', 'weight': 1},
#  {'source': 'Ford Beebe', 'target': 'James Algar', 'weight': 1},
#  {'source': 'Ford Beebe', 'target': 'Jim Handley', 'weight': 1},
#  {'source': 'Ford Beebe', 'target': 'Norman Ferguson', 'weight': 1},
#  {'source': 'Ford Beebe', 'target': 'Paul Satterfield', 'weight': 1},
#  {'source': 'Ford Beebe', 'target': 'Samuel Armstrong', 'weight': 1},
#  {'source': 'Ford Beebe', 'target': 'T. Hee', 'weight': 1},
#  {'source': 'Ford Beebe', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Hamilton Luske', 'target': 'James Algar', 'weight': 1},
#  {'source': 'Hamilton Luske', 'target': 'Jim Handley', 'weight': 1},
#  {'source': 'Hamilton Luske', 'target': 'Paul Satterfield', 'weight': 1},
#  {'source': 'Hamilton Luske', 'target': 'Samuel Armstrong', 'weight': 1},
#  {'source': 'James Algar', 'target': 'Jim Handley', 'weight': 1},
#  {'source': 'James Algar', 'target': 'Norman Ferguson', 'weight': 1},
#  {'source': 'James Algar', 'target': 'Paul Satterfield', 'weight': 2},
#  {'source': 'James Algar', 'target': 'Samuel Armstrong', 'weight': 2},
#  {'source': 'James Algar', 'target': 'T. Hee', 'weight': 1},
#  {'source': 'James Algar', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Jim Handley', 'target': 'Norman Ferguson', 'weight': 1},
#  {'source': 'Jim Handley', 'target': 'Paul Satterfield', 'weight': 1},
#  {'source': 'Jim Handley', 'target': 'Samuel Armstrong', 'weight': 1},
#  {'source': 'Jim Handley', 'target': 'T. Hee', 'weight': 1},
#  {'source': 'Jim Handley', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Norman Ferguson', 'target': 'Paul Satterfield', 'weight': 1},
#  {'source': 'Norman Ferguson', 'target': 'Samuel Armstrong', 'weight': 2},
#  {'source': 'Paul Satterfield', 'target': 'Samuel Armstrong', 'weight': 2},
#  {'source': 'Paul Satterfield', 'target': 'T. Hee', 'weight': 1},
#  {'source': 'Paul Satterfield', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Samuel Armstrong', 'target': 'T. Hee', 'weight': 1},
#  {'source': 'Samuel Armstrong', 'target': 'Wilfred Jackson', 'weight': 2},
#  {'source': 'Ben Sharpsteen', 'target': 'Sequence directors:', 'weight': 1},
#  {'source': 'Ben Sharpsteen', 'target': 'Supervising director:', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'Sequence directors:', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'Supervising director:', 'weight': 1},
#  {'source': 'Jack Kinney', 'target': 'Samuel Armstrong', 'weight': 1},
#  {'source': 'Jack Kinney', 'target': 'Sequence directors:', 'weight': 1},
#  {'source': 'Jack Kinney', 'target': 'Supervising director:', 'weight': 1},
#  {'source': 'Norman Ferguson', 'target': 'Sequence directors:', 'weight': 1},
#  {'source': 'Norman Ferguson', 'target': 'Supervising director:', 'weight': 1},
#  {'source': 'Samuel Armstrong', 'target': 'Sequence directors:', 'weight': 1},
#  {'source': 'Samuel Armstrong',
#   'target': 'Supervising director:',
#   'weight': 1},
#  {'source': 'Sequence directors:',
#   'target': 'Supervising director:',
#   'weight': 1},
#  {'source': 'Sequence directors:', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Supervising director:', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'David Hand', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'Graham Heid', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'Norman Wright', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'Sequence directors', 'weight': 1},
#  {'source': 'Bill Roberts', 'target': 'Supervising director', 'weight': 1},
#  {'source': 'David Hand', 'target': 'Graham Heid', 'weight': 1},
#  {'source': 'David Hand', 'target': 'James Algar', 'weight': 1},
#  {'source': 'David Hand', 'target': 'Norman Wright', 'weight': 1},
#  {'source': 'David Hand', 'target': 'Paul Satterfield', 'weight': 1},
#  {'source': 'David Hand', 'target': 'Samuel Armstrong', 'weight': 1},
#  {'source': 'David Hand', 'target': 'Sequence directors', 'weight': 1},
#  {'source': 'David Hand', 'target': 'Supervising director', 'weight': 1},
#  {'source': 'Graham Heid', 'target': 'James Algar', 'weight': 1},
#  {'source': 'Graham Heid', 'target': 'Norman Wright', 'weight': 1},
#  {'source': 'Graham Heid', 'target': 'Paul Satterfield', 'weight': 1},
#  {'source': 'Graham Heid', 'target': 'Samuel Armstrong', 'weight': 1},
#  {'source': 'Graham Heid', 'target': 'Sequence directors', 'weight': 1},
#  {'source': 'Graham Heid', 'target': 'Supervising director', 'weight': 1},
#  {'source': 'James Algar', 'target': 'Norman Wright', 'weight': 1},
#  {'source': 'James Algar', 'target': 'Sequence directors', 'weight': 1},
#  {'source': 'James Algar', 'target': 'Supervising director', 'weight': 1},
#  {'source': 'Norman Wright', 'target': 'Paul Satterfield', 'weight': 1},
#  {'source': 'Norman Wright', 'target': 'Samuel Armstrong', 'weight': 1},
#  {'source': 'Norman Wright', 'target': 'Sequence directors', 'weight': 1},
#  {'source': 'Norman Wright', 'target': 'Supervising director', 'weight': 1},
#  {'source': 'Paul Satterfield', 'target': 'Sequence directors', 'weight': 1},
#  {'source': 'Paul Satterfield', 'target': 'Supervising director', 'weight': 1},
#  {'source': 'Samuel Armstrong', 'target': 'Sequence directors', 'weight': 1},
#  {'source': 'Samuel Armstrong', 'target': 'Supervising director', 'weight': 1},
#  {'source': 'Sequence directors',
#   'target': 'Supervising director',
#   'weight': 1},
#  {'source': 'Clyde Geronimi', 'target': 'Hamilton Luske', 'weight': 7},
#  {'source': 'Clyde Geronimi', 'target': 'Jack Kinney', 'weight': 2},
#  {'source': 'Clyde Geronimi', 'target': 'Joshua Meador', 'weight': 1},
#  {'source': 'Clyde Geronimi', 'target': 'Robert Cormack', 'weight': 1},
#  {'source': 'Hamilton Luske', 'target': 'Joshua Meador', 'weight': 1},
#  {'source': 'Hamilton Luske', 'target': 'Robert Cormack', 'weight': 1},
#  {'source': 'Jack Kinney', 'target': 'Joshua Meador', 'weight': 1},
#  {'source': 'Jack Kinney', 'target': 'Robert Cormack', 'weight': 1},
#  {'source': 'Joshua Meador', 'target': 'Robert Cormack', 'weight': 1},
#  {'source': 'Animation:', 'target': 'Harve Foster', 'weight': 1},
#  {'source': 'Animation:', 'target': 'Live action:', 'weight': 1},
#  {'source': 'Animation:', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Harve Foster', 'target': 'Live action:', 'weight': 1},
#  {'source': 'Harve Foster', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Live action:', 'target': 'Wilfred Jackson', 'weight': 1},
#  {'source': 'Clyde Geronimi', 'target': 'Wilfred Jackson', 'weight': 5},
#  {'source': 'Clyde Geronimi (supervising)',
#   'target': 'Eric Larson',
#   'weight': 1},
#  {'source': 'Clyde Geronimi (supervising)',
#   'target': 'Les Clark',
#   'weight': 1},
#  {'source': 'Clyde Geronimi (supervising)',
#   'target': 'Wolfgang Reitherman',
#   'weight': 1},
#  {'source': 'Eric Larson', 'target': 'Les Clark', 'weight': 1},
#  {'source': 'Eric Larson', 'target': 'Wolfgang Reitherman', 'weight': 1},
#  {'source': 'Les Clark', 'target': 'Wolfgang Reitherman', 'weight': 1},
#  {'source': 'John McKimson', 'target': 'Ken Annakin', 'weight': 1},
#  {'source': 'Clyde Geronimi', 'target': 'Wolfgang Reitherman', 'weight': 1},
#  {'source': 'Hamilton Luske', 'target': 'Wolfgang Reitherman', 'weight': 1},
#  {'source': 'Art Stevens', 'target': 'John Lounsbery', 'weight': 1},
#  {'source': 'Art Stevens', 'target': 'Wolfgang Reitherman', 'weight': 1},
#  {'source': 'John Lounsbery', 'target': 'Wolfgang Reitherman', 'weight': 1},
#  {'source': 'Art Stevens', 'target': 'Richard Rich', 'weight': 1},
#  {'source': 'Art Stevens', 'target': 'Ted Berman', 'weight': 1},
#  {'source': 'Richard Rich', 'target': 'Ted Berman', 'weight': 2},
#  {'source': 'Burny Mattinson', 'target': 'Dave Michener', 'weight': 1},
#  {'source': 'Burny Mattinson', 'target': 'John Musker', 'weight': 1},
#  {'source': 'Burny Mattinson', 'target': 'Ron Clements', 'weight': 1},
#  {'source': 'Dave Michener', 'target': 'John Musker', 'weight': 1},
#  {'source': 'Dave Michener', 'target': 'Ron Clements', 'weight': 1},
#  {'source': 'John Musker', 'target': 'Ron Clements', 'weight': 6},
#  {'source': 'Gary Trousdale', 'target': 'Kirk Wise', 'weight': 3},
#  {'source': 'Rob Minkoff', 'target': 'Roger Allers', 'weight': 1},
#  {'source': 'Eric Goldberg', 'target': 'Mike Gabriel', 'weight': 1},
#  {'source': 'Barry Cook', 'target': 'Tony Bancroft', 'weight': 1},
#  {'source': 'Chris Buck', 'target': 'Kevin Lima', 'weight': 1},
#  {'source': 'Don Hahn', 'target': 'Eric Goldberg', 'weight': 2},
#  {'source': 'Don Hahn', 'target': 'Francis Glebas', 'weight': 2},
#  {'source': 'Don Hahn', 'target': 'Hendel Butoy', 'weight': 2},
#  {'source': 'Don Hahn', 'target': 'James Algar', 'weight': 2},
#  {'source': 'Don Hahn', 'target': 'Paul and Gaëtan Brizzi', 'weight': 2},
#  {'source': 'Don Hahn', 'target': 'Pixote Hunt', 'weight': 2},
#  {'source': 'Eric Goldberg', 'target': 'Francis Glebas', 'weight': 2},
#  {'source': 'Eric Goldberg', 'target': 'Hendel Butoy', 'weight': 2},
#  {'source': 'Eric Goldberg', 'target': 'James Algar', 'weight': 2},
#  {'source': 'Eric Goldberg', 'target': 'Paul and Gaëtan Brizzi', 'weight': 2},
#  {'source': 'Eric Goldberg', 'target': 'Pixote Hunt', 'weight': 2},
#  {'source': 'Francis Glebas', 'target': 'Hendel Butoy', 'weight': 2},
#  {'source': 'Francis Glebas', 'target': 'James Algar', 'weight': 2},
#  {'source': 'Francis Glebas', 'target': 'Paul and Gaëtan Brizzi', 'weight': 2},
#  {'source': 'Francis Glebas', 'target': 'Pixote Hunt', 'weight': 2},
#  {'source': 'Hendel Butoy', 'target': 'James Algar', 'weight': 2},
#  {'source': 'Hendel Butoy', 'target': 'Paul and Gaëtan Brizzi', 'weight': 2},
#  {'source': 'Hendel Butoy', 'target': 'Pixote Hunt', 'weight': 2},
#  {'source': 'James Algar', 'target': 'Paul and Gaëtan Brizzi', 'weight': 2},
#  {'source': 'James Algar', 'target': 'Pixote Hunt', 'weight': 2},
#  {'source': 'Paul and Gaëtan Brizzi', 'target': 'Pixote Hunt', 'weight': 2},
#  {'source': 'Eric Leighton', 'target': 'Ralph Zondag', 'weight': 1},
#  {'source': 'Chris Sanders', 'target': 'Dean DeBlois', 'weight': 1},
#  {'source': 'Aaron Blaise', 'target': 'Robert Walker', 'weight': 1},
#  {'source': 'John Sanford', 'target': 'Will Finn', 'weight': 1},
#  {'source': 'Alastair Fothergill', 'target': 'Mark Linfield', 'weight': 3},
#  {'source': 'Byron Howard', 'target': 'Chris Williams', 'weight': 1},
#  {'source': 'Jacques Cluzaud', 'target': 'Jacques Perrin', 'weight': 1},
#  {'source': 'Byron Howard', 'target': 'Nathan Greno', 'weight': 1},
#  {'source': 'Don Hall', 'target': 'Stephen J. Anderson', 'weight': 1},
#  {'source': 'Alastair Fothergill', 'target': 'Keith Scholey', 'weight': 2},
#  {'source': 'Brenda Chapman', 'target': 'Mark Andrews', 'weight': 1},
#  {'source': 'Chris Buck', 'target': 'Jennifer Lee', 'weight': 2},
#  {'source': 'Chris Williams', 'target': 'Don Hall', 'weight': 1},
#  {'source': 'Byron Howard', 'target': 'Rich Moore', 'weight': 1},
#  {'source': 'Espen Sandberg', 'target': 'Joachim Rønning', 'weight': 1},
#  {'source': 'Joe Johnston', 'target': 'Lasse Hallström', 'weight': 1},
#  {'source': 'Phil Johnston', 'target': 'Rich Moore', 'weight': 1}]

# %%
import json

directors = {"nodes": director_nodes, "links":director_links}

with open('directors.json', 'w') as json_file:
  json.dump(directors, json_file)

# %%
producers_nodes = [{"name":key,"count":producers[key]} for key in producers]
counter=collections.Counter(producers_edges)
producers_links = [{"source":key[0],"target":key[1],"weight":counter[key]} for key in counter]

# %%
producers = {"nodes": producers_nodes, "links":producers_links}

with open('producers.json', 'w') as json_file:
  json.dump(producers, json_file)

# %%
music_directors_nodes = [{"name":key,"count":music_directors[key]} for key in music_directors]
counter=collections.Counter(music_directors_edges)
music_directors_links = [{"source":key[0],"target":key[1],"weight":counter[key]} for key in counter]

music_directors = {"nodes": music_directors_nodes, "links":music_directors_links}

with open('music_directors.json', 'w') as json_file:
  json.dump(music_directors, json_file)
