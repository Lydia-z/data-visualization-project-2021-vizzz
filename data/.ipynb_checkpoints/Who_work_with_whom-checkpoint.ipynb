# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Bad key text.latex.unicode in file C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 112 ('text.latex.unicode : False # use "ucs" and "inputenc" LaTeX packages for handling')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key savefig.frameon in file C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 423 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key pgf.debug in file C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 444 ('pgf.debug           : False')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 475 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.1/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 476 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.4.1/matplotlibrc.template
# or from the matplotlib source distribution
# In C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\Hazel\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
data = pd.read_csv('./full_data.csv', error_bad_lines=False)
print('size of the third dataset is ', data.shape)
data.head()
# Out:
# size of the third dataset is  (224, 14)
#    Unnamed: 0            title  Running time     Budget   Box office  \
# 0           0        Pinocchio          88.0  2600000.0  164000000.0
# 1           1         Fantasia         126.0  2280000.0   83300000.0
# 2           2            Dumbo          64.0   950000.0    1300000.0
# 3           3            Bambi          70.0   858000.0  267400000.0
# 4           4  Make Mine Music          75.0  1350000.0    3275000.0
#
#   Release date  imdb  metascore  rotten_tomatoes  \
# 0   1940-02-07   7.4       99.0              100
# 1   1940-11-13   7.8       96.0               95
# 2   1941-10-23   7.2       96.0               98
# 3   1942-08-09   7.3       91.0               90
# 4   1946-04-20   6.3       60.0               70
#
#                                          Directed by  \
# 0  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 1  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 2  ['Supervising director:', 'Ben Sharpsteen', 'S...
# 3  ['Supervising director', 'David Hand', 'Sequen...
# 4  ['Jack Kinney', 'Clyde Geronimi', 'Hamilton Lu...
#
#                          Produced by  \
# 0                        Walt Disney
# 1  ['Walt Disney', 'Ben Sharpsteen']
# 2                        Walt Disney
# 3                        Walt Disney
# 4                        Walt Disney
#
#                                             Music by  \
# 0                 ['Leigh Harline', 'Paul J. Smith']
# 1                                        See program
# 2              ['Frank Churchill', 'Oliver Wallace']
# 3             ['Frank Churchill', 'Edward H. Plumb']
# 4  ['Eliot Daniel', 'Ken Darby', 'Charles Wolcott...
#
#                                       Distributed by  year
# 0                                 RKO Radio Pictures  1940
# 1  ['Walt Disney Productions', 'RKO Radio Pictures']  1940
# 2                                 RKO Radio Pictures  1941
# 3                                 RKO Radio Pictures  1942
# 4                           RKO Radio Pictures, Inc.  1946

# %%
directors ={} #{name: count}
producers = {}
music_directors = {}

directors_edges = [] #[(source, target)...]
producers_edges = []
music_directors_edges = []

# %%
def get_nodes_edges(string, nodes, links):
    if(string == 'nan'):
        return nodes, links
    # if the string is with []
    #print(string)
    if('[' in string and ']' in string):
        # get rid of the []
        string = string[1:-1]
        
    names = sorted(string.split(', '))
    for name in names:
        # if name string with ''
        if('\'' in name):
            name = name[1:-1]
        # get rid of '(' or ')' or '(blahblahblah)' as they are all explaination
        if(name.startswith('(')):
            continue
        if(name.startswith(')')):
            continue
            
        if name in nodes:
            nodes[name] += 1
        else:
            nodes[name] = 1
    
    for i in range(len(names)):
        # if name string with ''
        if('\'' in names[i]):
            names[i] = names[i][1:-1]
        # get rid of '(' or ')' or '(blahblahblah)' as they are all explaination
        if(names[i].startswith('(')):
            continue
        if(names[i].startswith(')')):
            continue
            
        for j in range(i+1, len(names)):
            # if name string with ''
            if('\'' in names[j]):
                names[j] = names[j][1:-1]
                # get rid of '(' or ')' or '(blahblahblah)' as they are all explaination
            if(names[j].startswith('(')):
                continue
            if(names[j].startswith(')')):
                continue
            links.append((names[i],names[j]))
            
    return nodes, links

# %%
for ind, row in data.iterrows():
    if(pd.notna(row['Directed by'])):
        directors,directors_edges = get_nodes_edges(row['Directed by'],directors,directors_edges)
    if(pd.notna(row['Produced by'])):
        producers,producers_edges = get_nodes_edges(row['Produced by'],producers,producers_edges)
    if(pd.notna(row['Music by'])):
        music_directors,music_directors_edges = get_nodes_edges(row['Music by'],music_directors,music_directors_edges)

# %%
import collections
counter=collections.Counter(directors_edges)

# %%
director_nodes = [{"name":key,"count":directors[key]} for key in directors]

# %%
director_nodes
# Out:
# [{'name': 'Ben Sharpsteen', 'count': 15},
#  {'name': 'Bill Roberts', 'count': 20},
#  {'name': 'Hamilton Luske', 'count': 45},
#  {'name': 'Jack Kinney', 'count': 20},
#  {'name': 'Norman Ferguson', 'count': 15},
#  {'name': 'T. Hee', 'count': 10},
#  {'name': 'Wilfred Jackson', 'count': 45},
#  {'name': 'David D. Hand', 'count': 5},
#  {'name': 'Ford Beebe', 'count': 5},
#  {'name': 'James Algar', 'count': 25},
#  {'name': 'Jim Handley', 'count': 5},
#  {'name': 'Paul Satterfield', 'count': 10},
#  {'name': 'Samuel Armstrong', 'count': 15},
#  {'name': 'Sequence directors:', 'count': 5},
#  {'name': 'Supervising director:', 'count': 5},
#  {'name': 'David Hand', 'count': 5},
#  {'name': 'Graham Heid', 'count': 5},
#  {'name': 'Norman Wright', 'count': 5},
#  {'name': 'Sequence directors', 'count': 5},
#  {'name': 'Supervising director', 'count': 5},
#  {'name': 'Clyde Geronimi', 'count': 35},
#  {'name': 'Joshua Meador', 'count': 5},
#  {'name': 'Robert Cormack', 'count': 5},
#  {'name': 'Animation:', 'count': 5},
#  {'name': 'Harve Foster', 'count': 5},
#  {'name': 'Live action:', 'count': 5},
#  {'name': 'Richard Fleischer', 'count': 5},
#  {'name': 'Clyde Geronimi (supervising)', 'count': 5},
#  {'name': 'Eric Larson', 'count': 5},
#  {'name': 'Les Clark', 'count': 5},
#  {'name': 'Wolfgang Reitherman', 'count': 35},
#  {'name': 'Charles Barton', 'count': 5},
#  {'name': 'John McKimson', 'count': 5},
#  {'name': 'Ken Annakin', 'count': 5},
#  {'name': 'Jack Donohue', 'count': 5},
#  {'name': 'Robert Stevenson', 'count': 15},
#  {'name': 'Gary Nelson', 'count': 15},
#  {'name': 'Art Stevens', 'count': 10},
#  {'name': 'John Lounsbery', 'count': 5},
#  {'name': 'Don Chaffey', 'count': 5},
#  {'name': 'Robert Altman', 'count': 5},
#  {'name': 'Matthew Robbins', 'count': 5},
#  {'name': 'Richard Rich', 'count': 10},
#  {'name': 'Ted Berman', 'count': 10},
#  {'name': 'Tim Hunter', 'count': 5},
#  {'name': 'Walter Murch', 'count': 5},
#  {'name': 'Burny Mattinson', 'count': 5},
#  {'name': 'Dave Michener', 'count': 5},
#  {'name': 'John Musker', 'count': 30},
#  {'name': 'Ron Clements', 'count': 30},
#  {'name': 'Randal Kleiser', 'count': 15},
#  {'name': 'George Scribner', 'count': 5},
#  {'name': 'Joe Johnston', 'count': 15},
#  {'name': 'Gary Trousdale', 'count': 15},
#  {'name': 'Kirk Wise', 'count': 15},
#  {'name': 'Kenny Ortega', 'count': 5},
#  {'name': 'Stephen Herek', 'count': 15},
#  {'name': 'Brian Henson', 'count': 10},
#  {'name': 'Jon Turteltaub', 'count': 20},
#  {'name': 'Henry Selick', 'count': 10},
#  {'name': 'Rupert Wainwright', 'count': 5},
#  {'name': 'Rob Minkoff', 'count': 10},
#  {'name': 'Roger Allers', 'count': 5},
#  {'name': 'William Dear', 'count': 5},
#  {'name': 'John Pasquin', 'count': 10},
#  {'name': 'James Orr', 'count': 5},
#  {'name': 'Eric Goldberg', 'count': 15},
#  {'name': 'Mike Gabriel', 'count': 5},
#  {'name': 'Simon Wincer', 'count': 5},
#  {'name': 'Michael Gottlieb', 'count': 5},
#  {'name': 'John Lasseter', 'count': 25},
#  {'name': 'David M. Evans', 'count': 5},
#  {'name': 'Sam Weisman', 'count': 5},
#  {'name': 'Les Mayfield', 'count': 5},
#  {'name': 'Stanley Tong', 'count': 5},
#  {'name': 'Barry Cook', 'count': 5},
#  {'name': 'Tony Bancroft', 'count': 5},
#  {'name': 'Nancy Meyers', 'count': 5},
#  {'name': 'Ron Underwood', 'count': 5},
#  {'name': 'Donald Petrie', 'count': 5},
#  {'name': 'Chris Buck', 'count': 15},
#  {'name': 'Kevin Lima', 'count': 15},
#  {'name': 'David Kellogg', 'count': 5},
#  {'name': 'Don Hahn', 'count': 10},
#  {'name': 'Francis Glebas', 'count': 15},
#  {'name': 'Hendel Butoy', 'count': 10},
#  {'name': 'Paul and Gaëtan Brizzi', 'count': 10},
#  {'name': 'Pixote Hunt', 'count': 10},
#  {'name': 'Jun Falkenstein', 'count': 5},
#  {'name': 'Eric Leighton', 'count': 5},
#  {'name': 'Ralph Zondag', 'count': 5},
#  {'name': 'Boaz Yakin', 'count': 5},
#  {'name': 'Mark Dindal', 'count': 10},
#  {'name': 'Chuck Sheetz', 'count': 5},
#  {'name': 'Garry Marshall', 'count': 10},
#  {'name': 'Tim Hill', 'count': 5},
#  {'name': 'Pete Docter', 'count': 15},
#  {'name': 'Brian Levant', 'count': 5},
#  {'name': 'Robin Budd', 'count': 5},
#  {'name': 'John Lee Hancock', 'count': 10},
#  {'name': 'Chris Sanders', 'count': 5},
#  {'name': 'Dean DeBlois', 'count': 5},
#  {'name': 'Peter Hastings', 'count': 5},
#  {'name': 'Jay Russell', 'count': 5},
#  {'name': 'Michael Lembeck', 'count': 10},
#  {'name': 'Steve Trenbirth', 'count': 5},
#  {'name': 'James Cameron', 'count': 5},
#  {'name': 'Andrew Davis', 'count': 5},
#  {'name': 'Jim Fall', 'count': 5},
#  {'name': 'Andrew Stanton', 'count': 20},
#  {'name': 'Gore Verbinski', 'count': 20},
#  {'name': 'Mark Waters', 'count': 5},
#  {'name': 'Aaron Blaise', 'count': 5},
#  {'name': 'Robert Walker', 'count': 5},
#  {'name': "avin O'Conno", 'count': 5},
#  {'name': 'Sara Sugarman', 'count': 5},
#  {'name': 'John Sanford', 'count': 5},
#  {'name': 'Will Finn', 'count': 5},
#  {'name': 'Frank Coraci', 'count': 5},
#  {'name': 'Luc Jacquet', 'count': 5},
#  {'name': 'Frank Nissen', 'count': 5},
#  {'name': 'Adam Shankman', 'count': 10},
#  {'name': 'Tim Fywell', 'count': 5},
#  {'name': 'Gary Chapman', 'count': 5},
#  {'name': 'Angela Robinson', 'count': 5},
#  {'name': 'Mike Mitchell', 'count': 5},
#  {'name': 'Bill Paxton', 'count': 5},
#  {'name': 'Andrew Adamson', 'count': 10},
#  {'name': 'James Gartner', 'count': 5},
#  {'name': 'George Butler', 'count': 5},
#  {'name': 'Frank Marshall', 'count': 5},
#  {'name': 'Brian Robbins', 'count': 5},
#  {'name': 'Steve "Spaz" Williams', 'count': 5},
#  {'name': 'Ericson Core', 'count': 5},
#  {'name': 'Gábor Csupó', 'count': 5},
#  {'name': 'Brad Bird', 'count': 15},
#  {'name': 'Frederik Du Chau', 'count': 5},
#  {'name': 'Andy Fickman', 'count': 10},
#  {'name': 'Alastair Fothergill', 'count': 25},
#  {'name': 'Mark Linfield', 'count': 15},
#  {'name': 'Bruce Hendricks', 'count': 5},
#  {'name': 'Roger Kumble', 'count': 5},
#  {'name': 'Raja Gosnell', 'count': 10},
#  {'name': 'Byron Howard', 'count': 15},
#  {'name': 'Chris Williams', 'count': 10},
#  {'name': 'Peter Chelsom', 'count': 5},
#  {'name': 'Hoyt H. Yeatman Jr.', 'count': 5},
#  {'name': 'Jacques Cluzaud', 'count': 5},
#  {'name': 'Jacques Perrin', 'count': 5},
#  {'name': 'Robert Zemeckis', 'count': 5},
#  {'name': 'Walt Becker', 'count': 5},
#  {'name': 'Tim Burton', 'count': 15},
#  {'name': 'Mike Newell', 'count': 5},
#  {'name': 'Lee Unkrich', 'count': 10},
#  {'name': 'Hiromasa Yonebayashi', 'count': 5},
#  {'name': 'Randall Wallace', 'count': 5},
#  {'name': 'Nathan Greno', 'count': 5},
#  {'name': 'Joseph Kosinski', 'count': 5},
#  {'name': 'Simon Wells', 'count': 5},
#  {'name': 'Don Hall', 'count': 10},
#  {'name': 'Stephen J. Anderson', 'count': 5},
#  {'name': 'Keith Scholey', 'count': 10},
#  {'name': 'Joe Nussbaum', 'count': 5},
#  {'name': 'Rob Marshall', 'count': 15},
#  {'name': 'James Bobin', 'count': 15},
#  {'name': 'Brenda Chapman', 'count': 5},
#  {'name': 'Mark Andrews', 'count': 5},
#  {'name': 'Peter Hedges', 'count': 5},
#  {'name': 'Rich Moore', 'count': 15},
#  {'name': 'Sam Raimi', 'count': 5},
#  {'name': 'Dan Scanlon', 'count': 10},
#  {'name': 'Klay Hall', 'count': 5},
#  {'name': 'Jennifer Lee', 'count': 10},
#  {'name': 'Craig Gillespie', 'count': 10},
#  {'name': 'Robert Stromberg', 'count': 5},
#  {'name': 'Bobs Gannaway', 'count': 5},
#  {'name': 'Miguel Arteta', 'count': 5},
#  {'name': 'Niki Caro', 'count': 10},
#  {'name': 'Kenneth Branagh', 'count': 5},
#  {'name': 'Peter Sohn', 'count': 5},
#  {'name': 'Jon Favreau', 'count': 10},
#  {'name': 'Steven Spielberg', 'count': 5},
#  {'name': 'David Lowery', 'count': 5},
#  {'name': 'Lu Chuan', 'count': 5},
#  {'name': 'Mira Nair', 'count': 5},
#  {'name': 'Bill Condon', 'count': 5},
#  {'name': 'Espen Sandberg', 'count': 5},
#  {'name': 'Joachim Rønning', 'count': 10},
#  {'name': 'Brian Fee', 'count': 5},
#  {'name': 'Ava DuVernay', 'count': 5},
#  {'name': 'Lasse Hallström', 'count': 5},
#  {'name': 'Phil Johnston', 'count': 5},
#  {'name': 'Josh Cooley', 'count': 5}]

# %%
director_links = [{"source":key[0],"target":key[1],"weight":counter[key]} for key in counter]

# %%
director_links
# Out:
# [{'source': 'Ben Sharpsteen', 'target': 'Bill Roberts', 'weight': 12},
#  {'source': 'Ben Sharpsteen', 'target': 'Hamilton Luske', 'weight': 8},
#  {'source': 'Ben Sharpsteen', 'target': 'Jack Kinney', 'weight': 8},
#  {'source': 'Ben Sharpsteen', 'target': 'Norman Ferguson', 'weight': 12},
#  {'source': 'Ben Sharpsteen', 'target': 'T. Hee', 'weight': 8},
#  {'source': 'Ben Sharpsteen', 'target': 'Wilfred Jackson', 'weight': 12},
#  {'source': 'Bill Roberts', 'target': 'Hamilton Luske', 'weight': 8},
#  {'source': 'Bill Roberts', 'target': 'Jack Kinney', 'weight': 8},
#  {'source': 'Bill Roberts', 'target': 'Norman Ferguson', 'weight': 12},
#  {'source': 'Bill Roberts', 'target': 'T. Hee', 'weight': 8},
#  {'source': 'Bill Roberts', 'target': 'Wilfred Jackson', 'weight': 12},
#  {'source': 'Hamilton Luske', 'target': 'Jack Kinney', 'weight': 12},
#  {'source': 'Hamilton Luske', 'target': 'Norman Ferguson', 'weight': 8},
#  {'source': 'Hamilton Luske', 'target': 'T. Hee', 'weight': 8},
#  {'source': 'Hamilton Luske', 'target': 'Wilfred Jackson', 'weight': 28},
#  {'source': 'Jack Kinney', 'target': 'Norman Ferguson', 'weight': 8},
#  {'source': 'Jack Kinney', 'target': 'T. Hee', 'weight': 4},
#  {'source': 'Jack Kinney', 'target': 'Wilfred Jackson', 'weight': 12},
#  {'source': 'Norman Ferguson', 'target': 'T. Hee', 'weight': 8},
#  {'source': 'Norman Ferguson', 'target': 'Wilfred Jackson', 'weight': 12},
#  {'source': 'T. Hee', 'target': 'Wilfred Jackson', 'weight': 8},
#  {'source': 'Ben Sharpsteen', 'target': 'David D. Hand', 'weight': 4},
#  {'source': 'Ben Sharpsteen', 'target': 'Ford Beebe', 'weight': 4},
#  {'source': 'Ben Sharpsteen', 'target': 'James Algar', 'weight': 4},
#  {'source': 'Ben Sharpsteen', 'target': 'Jim Handley', 'weight': 4},
#  {'source': 'Ben Sharpsteen', 'target': 'Paul Satterfield', 'weight': 4},
#  {'source': 'Ben Sharpsteen', 'target': 'Samuel Armstrong', 'weight': 8},
#  {'source': 'Bill Roberts', 'target': 'David D. Hand', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'Ford Beebe', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'James Algar', 'weight': 8},
#  {'source': 'Bill Roberts', 'target': 'Jim Handley', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'Paul Satterfield', 'weight': 8},
#  {'source': 'Bill Roberts', 'target': 'Samuel Armstrong', 'weight': 12},
#  {'source': 'David D. Hand', 'target': 'Ford Beebe', 'weight': 4},
#  {'source': 'David D. Hand', 'target': 'Hamilton Luske', 'weight': 4},
#  {'source': 'David D. Hand', 'target': 'James Algar', 'weight': 4},
#  {'source': 'David D. Hand', 'target': 'Jim Handley', 'weight': 4},
#  {'source': 'David D. Hand', 'target': 'Norman Ferguson', 'weight': 4},
#  {'source': 'David D. Hand', 'target': 'Paul Satterfield', 'weight': 4},
#  {'source': 'David D. Hand', 'target': 'Samuel Armstrong', 'weight': 4},
#  {'source': 'David D. Hand', 'target': 'T. Hee', 'weight': 4},
#  {'source': 'David D. Hand', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Ford Beebe', 'target': 'Hamilton Luske', 'weight': 4},
#  {'source': 'Ford Beebe', 'target': 'James Algar', 'weight': 4},
#  {'source': 'Ford Beebe', 'target': 'Jim Handley', 'weight': 4},
#  {'source': 'Ford Beebe', 'target': 'Norman Ferguson', 'weight': 4},
#  {'source': 'Ford Beebe', 'target': 'Paul Satterfield', 'weight': 4},
#  {'source': 'Ford Beebe', 'target': 'Samuel Armstrong', 'weight': 4},
#  {'source': 'Ford Beebe', 'target': 'T. Hee', 'weight': 4},
#  {'source': 'Ford Beebe', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Hamilton Luske', 'target': 'James Algar', 'weight': 4},
#  {'source': 'Hamilton Luske', 'target': 'Jim Handley', 'weight': 4},
#  {'source': 'Hamilton Luske', 'target': 'Paul Satterfield', 'weight': 4},
#  {'source': 'Hamilton Luske', 'target': 'Samuel Armstrong', 'weight': 4},
#  {'source': 'James Algar', 'target': 'Jim Handley', 'weight': 4},
#  {'source': 'James Algar', 'target': 'Norman Ferguson', 'weight': 4},
#  {'source': 'James Algar', 'target': 'Paul Satterfield', 'weight': 8},
#  {'source': 'James Algar', 'target': 'Samuel Armstrong', 'weight': 8},
#  {'source': 'James Algar', 'target': 'T. Hee', 'weight': 4},
#  {'source': 'James Algar', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Jim Handley', 'target': 'Norman Ferguson', 'weight': 4},
#  {'source': 'Jim Handley', 'target': 'Paul Satterfield', 'weight': 4},
#  {'source': 'Jim Handley', 'target': 'Samuel Armstrong', 'weight': 4},
#  {'source': 'Jim Handley', 'target': 'T. Hee', 'weight': 4},
#  {'source': 'Jim Handley', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Norman Ferguson', 'target': 'Paul Satterfield', 'weight': 4},
#  {'source': 'Norman Ferguson', 'target': 'Samuel Armstrong', 'weight': 8},
#  {'source': 'Paul Satterfield', 'target': 'Samuel Armstrong', 'weight': 8},
#  {'source': 'Paul Satterfield', 'target': 'T. Hee', 'weight': 4},
#  {'source': 'Paul Satterfield', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Samuel Armstrong', 'target': 'T. Hee', 'weight': 4},
#  {'source': 'Samuel Armstrong', 'target': 'Wilfred Jackson', 'weight': 8},
#  {'source': 'Ben Sharpsteen', 'target': 'Sequence directors:', 'weight': 4},
#  {'source': 'Ben Sharpsteen', 'target': 'Supervising director:', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'Sequence directors:', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'Supervising director:', 'weight': 4},
#  {'source': 'Jack Kinney', 'target': 'Samuel Armstrong', 'weight': 4},
#  {'source': 'Jack Kinney', 'target': 'Sequence directors:', 'weight': 4},
#  {'source': 'Jack Kinney', 'target': 'Supervising director:', 'weight': 4},
#  {'source': 'Norman Ferguson', 'target': 'Sequence directors:', 'weight': 4},
#  {'source': 'Norman Ferguson', 'target': 'Supervising director:', 'weight': 4},
#  {'source': 'Samuel Armstrong', 'target': 'Sequence directors:', 'weight': 4},
#  {'source': 'Samuel Armstrong',
#   'target': 'Supervising director:',
#   'weight': 4},
#  {'source': 'Sequence directors:',
#   'target': 'Supervising director:',
#   'weight': 4},
#  {'source': 'Sequence directors:', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Supervising director:', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'David Hand', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'Graham Heid', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'Norman Wright', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'Sequence directors', 'weight': 4},
#  {'source': 'Bill Roberts', 'target': 'Supervising director', 'weight': 4},
#  {'source': 'David Hand', 'target': 'Graham Heid', 'weight': 4},
#  {'source': 'David Hand', 'target': 'James Algar', 'weight': 4},
#  {'source': 'David Hand', 'target': 'Norman Wright', 'weight': 4},
#  {'source': 'David Hand', 'target': 'Paul Satterfield', 'weight': 4},
#  {'source': 'David Hand', 'target': 'Samuel Armstrong', 'weight': 4},
#  {'source': 'David Hand', 'target': 'Sequence directors', 'weight': 4},
#  {'source': 'David Hand', 'target': 'Supervising director', 'weight': 4},
#  {'source': 'Graham Heid', 'target': 'James Algar', 'weight': 4},
#  {'source': 'Graham Heid', 'target': 'Norman Wright', 'weight': 4},
#  {'source': 'Graham Heid', 'target': 'Paul Satterfield', 'weight': 4},
#  {'source': 'Graham Heid', 'target': 'Samuel Armstrong', 'weight': 4},
#  {'source': 'Graham Heid', 'target': 'Sequence directors', 'weight': 4},
#  {'source': 'Graham Heid', 'target': 'Supervising director', 'weight': 4},
#  {'source': 'James Algar', 'target': 'Norman Wright', 'weight': 4},
#  {'source': 'James Algar', 'target': 'Sequence directors', 'weight': 4},
#  {'source': 'James Algar', 'target': 'Supervising director', 'weight': 4},
#  {'source': 'Norman Wright', 'target': 'Paul Satterfield', 'weight': 4},
#  {'source': 'Norman Wright', 'target': 'Samuel Armstrong', 'weight': 4},
#  {'source': 'Norman Wright', 'target': 'Sequence directors', 'weight': 4},
#  {'source': 'Norman Wright', 'target': 'Supervising director', 'weight': 4},
#  {'source': 'Paul Satterfield', 'target': 'Sequence directors', 'weight': 4},
#  {'source': 'Paul Satterfield', 'target': 'Supervising director', 'weight': 4},
#  {'source': 'Samuel Armstrong', 'target': 'Sequence directors', 'weight': 4},
#  {'source': 'Samuel Armstrong', 'target': 'Supervising director', 'weight': 4},
#  {'source': 'Sequence directors',
#   'target': 'Supervising director',
#   'weight': 4},
#  {'source': 'Clyde Geronimi', 'target': 'Hamilton Luske', 'weight': 28},
#  {'source': 'Clyde Geronimi', 'target': 'Jack Kinney', 'weight': 8},
#  {'source': 'Clyde Geronimi', 'target': 'Joshua Meador', 'weight': 4},
#  {'source': 'Clyde Geronimi', 'target': 'Robert Cormack', 'weight': 4},
#  {'source': 'Hamilton Luske', 'target': 'Joshua Meador', 'weight': 4},
#  {'source': 'Hamilton Luske', 'target': 'Robert Cormack', 'weight': 4},
#  {'source': 'Jack Kinney', 'target': 'Joshua Meador', 'weight': 4},
#  {'source': 'Jack Kinney', 'target': 'Robert Cormack', 'weight': 4},
#  {'source': 'Joshua Meador', 'target': 'Robert Cormack', 'weight': 4},
#  {'source': 'Animation:', 'target': 'Harve Foster', 'weight': 4},
#  {'source': 'Animation:', 'target': 'Live action:', 'weight': 4},
#  {'source': 'Animation:', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Harve Foster', 'target': 'Live action:', 'weight': 4},
#  {'source': 'Harve Foster', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Live action:', 'target': 'Wilfred Jackson', 'weight': 4},
#  {'source': 'Clyde Geronimi', 'target': 'Wilfred Jackson', 'weight': 20},
#  {'source': 'Clyde Geronimi (supervising)',
#   'target': 'Eric Larson',
#   'weight': 4},
#  {'source': 'Clyde Geronimi (supervising)',
#   'target': 'Les Clark',
#   'weight': 4},
#  {'source': 'Clyde Geronimi (supervising)',
#   'target': 'Wolfgang Reitherman',
#   'weight': 4},
#  {'source': 'Eric Larson', 'target': 'Les Clark', 'weight': 4},
#  {'source': 'Eric Larson', 'target': 'Wolfgang Reitherman', 'weight': 4},
#  {'source': 'Les Clark', 'target': 'Wolfgang Reitherman', 'weight': 4},
#  {'source': 'John McKimson', 'target': 'Ken Annakin', 'weight': 4},
#  {'source': 'Clyde Geronimi', 'target': 'Wolfgang Reitherman', 'weight': 4},
#  {'source': 'Hamilton Luske', 'target': 'Wolfgang Reitherman', 'weight': 4},
#  {'source': 'Art Stevens', 'target': 'John Lounsbery', 'weight': 4},
#  {'source': 'Art Stevens', 'target': 'Wolfgang Reitherman', 'weight': 4},
#  {'source': 'John Lounsbery', 'target': 'Wolfgang Reitherman', 'weight': 4},
#  {'source': 'Art Stevens', 'target': 'Richard Rich', 'weight': 4},
#  {'source': 'Art Stevens', 'target': 'Ted Berman', 'weight': 4},
#  {'source': 'Richard Rich', 'target': 'Ted Berman', 'weight': 8},
#  {'source': 'Burny Mattinson', 'target': 'Dave Michener', 'weight': 4},
#  {'source': 'Burny Mattinson', 'target': 'John Musker', 'weight': 4},
#  {'source': 'Burny Mattinson', 'target': 'Ron Clements', 'weight': 4},
#  {'source': 'Dave Michener', 'target': 'John Musker', 'weight': 4},
#  {'source': 'Dave Michener', 'target': 'Ron Clements', 'weight': 4},
#  {'source': 'John Musker', 'target': 'Ron Clements', 'weight': 24},
#  {'source': 'Gary Trousdale', 'target': 'Kirk Wise', 'weight': 12},
#  {'source': 'Rob Minkoff', 'target': 'Roger Allers', 'weight': 4},
#  {'source': 'Eric Goldberg', 'target': 'Mike Gabriel', 'weight': 4},
#  {'source': 'Barry Cook', 'target': 'Tony Bancroft', 'weight': 4},
#  {'source': 'Chris Buck', 'target': 'Kevin Lima', 'weight': 4},
#  {'source': 'Don Hahn', 'target': 'Eric Goldberg', 'weight': 8},
#  {'source': 'Don Hahn', 'target': 'Francis Glebas', 'weight': 8},
#  {'source': 'Don Hahn', 'target': 'Hendel Butoy', 'weight': 8},
#  {'source': 'Don Hahn', 'target': 'James Algar', 'weight': 8},
#  {'source': 'Don Hahn', 'target': 'Paul and Gaëtan Brizzi', 'weight': 8},
#  {'source': 'Don Hahn', 'target': 'Pixote Hunt', 'weight': 8},
#  {'source': 'Eric Goldberg', 'target': 'Francis Glebas', 'weight': 8},
#  {'source': 'Eric Goldberg', 'target': 'Hendel Butoy', 'weight': 8},
#  {'source': 'Eric Goldberg', 'target': 'James Algar', 'weight': 8},
#  {'source': 'Eric Goldberg', 'target': 'Paul and Gaëtan Brizzi', 'weight': 8},
#  {'source': 'Eric Goldberg', 'target': 'Pixote Hunt', 'weight': 8},
#  {'source': 'Francis Glebas', 'target': 'Hendel Butoy', 'weight': 8},
#  {'source': 'Francis Glebas', 'target': 'James Algar', 'weight': 8},
#  {'source': 'Francis Glebas', 'target': 'Paul and Gaëtan Brizzi', 'weight': 8},
#  {'source': 'Francis Glebas', 'target': 'Pixote Hunt', 'weight': 8},
#  {'source': 'Hendel Butoy', 'target': 'James Algar', 'weight': 8},
#  {'source': 'Hendel Butoy', 'target': 'Paul and Gaëtan Brizzi', 'weight': 8},
#  {'source': 'Hendel Butoy', 'target': 'Pixote Hunt', 'weight': 8},
#  {'source': 'James Algar', 'target': 'Paul and Gaëtan Brizzi', 'weight': 8},
#  {'source': 'James Algar', 'target': 'Pixote Hunt', 'weight': 8},
#  {'source': 'Paul and Gaëtan Brizzi', 'target': 'Pixote Hunt', 'weight': 8},
#  {'source': 'Eric Leighton', 'target': 'Ralph Zondag', 'weight': 4},
#  {'source': 'Chris Sanders', 'target': 'Dean DeBlois', 'weight': 4},
#  {'source': 'Aaron Blaise', 'target': 'Robert Walker', 'weight': 4},
#  {'source': 'John Sanford', 'target': 'Will Finn', 'weight': 4},
#  {'source': 'Alastair Fothergill', 'target': 'Mark Linfield', 'weight': 12},
#  {'source': 'Byron Howard', 'target': 'Chris Williams', 'weight': 4},
#  {'source': '(co-director)', 'target': 'Jacques Cluzaud', 'weight': 4},
#  {'source': '(co-director)', 'target': 'Jacques Perrin', 'weight': 4},
#  {'source': 'Jacques Cluzaud', 'target': 'Jacques Perrin', 'weight': 4},
#  {'source': 'Byron Howard', 'target': 'Nathan Greno', 'weight': 4},
#  {'source': 'Don Hall', 'target': 'Stephen J. Anderson', 'weight': 4},
#  {'source': 'Alastair Fothergill', 'target': 'Keith Scholey', 'weight': 8},
#  {'source': 'Brenda Chapman', 'target': 'Mark Andrews', 'weight': 4},
#  {'source': 'Chris Buck', 'target': 'Jennifer Lee', 'weight': 8},
#  {'source': 'Chris Williams', 'target': 'Don Hall', 'weight': 4},
#  {'source': 'Byron Howard', 'target': 'Rich Moore', 'weight': 4},
#  {'source': 'Espen Sandberg', 'target': 'Joachim Rønning', 'weight': 4},
#  {'source': 'Joe Johnston', 'target': 'Lasse Hallström', 'weight': 4},
#  {'source': 'Phil Johnston', 'target': 'Rich Moore', 'weight': 4},
#  {'source': 'en Sharpste', 'target': 'ill Rober', 'weight': 3},
#  {'source': 'en Sharpste', 'target': 'amilton Lus', 'weight': 2},
#  {'source': 'en Sharpste', 'target': 'ack Kinn', 'weight': 2},
#  {'source': 'en Sharpste', 'target': 'orman Fergus', 'weight': 3},
#  {'source': 'en Sharpste', 'target': '. H', 'weight': 2},
#  {'source': 'en Sharpste', 'target': 'ilfred Jacks', 'weight': 3},
#  {'source': 'ill Rober', 'target': 'amilton Lus', 'weight': 2},
#  {'source': 'ill Rober', 'target': 'ack Kinn', 'weight': 2},
#  {'source': 'ill Rober', 'target': 'orman Fergus', 'weight': 3},
#  {'source': 'ill Rober', 'target': '. H', 'weight': 2},
#  {'source': 'ill Rober', 'target': 'ilfred Jacks', 'weight': 3},
#  {'source': 'amilton Lus', 'target': 'ack Kinn', 'weight': 3},
#  {'source': 'amilton Lus', 'target': 'orman Fergus', 'weight': 2},
#  {'source': 'amilton Lus', 'target': '. H', 'weight': 2},
#  {'source': 'amilton Lus', 'target': 'ilfred Jacks', 'weight': 7},
#  {'source': 'ack Kinn', 'target': 'orman Fergus', 'weight': 2},
#  {'source': 'ack Kinn', 'target': '. H', 'weight': 1},
#  {'source': 'ack Kinn', 'target': 'ilfred Jacks', 'weight': 3},
#  {'source': 'orman Fergus', 'target': '. H', 'weight': 2},
#  {'source': 'orman Fergus', 'target': 'ilfred Jacks', 'weight': 3},
#  {'source': '. H', 'target': 'ilfred Jacks', 'weight': 2},
#  {'source': 'en Sharpste', 'target': 'avid D. Ha', 'weight': 1},
#  {'source': 'en Sharpste', 'target': 'ord Bee', 'weight': 1},
#  {'source': 'en Sharpste', 'target': 'ames Alg', 'weight': 1},
#  {'source': 'en Sharpste', 'target': 'im Handl', 'weight': 1},
#  {'source': 'en Sharpste', 'target': 'aul Satterfie', 'weight': 1},
#  {'source': 'en Sharpste', 'target': 'amuel Armstro', 'weight': 2},
#  {'source': 'ill Rober', 'target': 'avid D. Ha', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'ord Bee', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'ames Alg', 'weight': 2},
#  {'source': 'ill Rober', 'target': 'im Handl', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'aul Satterfie', 'weight': 2},
#  {'source': 'ill Rober', 'target': 'amuel Armstro', 'weight': 3},
#  {'source': 'avid D. Ha', 'target': 'ord Bee', 'weight': 1},
#  {'source': 'avid D. Ha', 'target': 'amilton Lus', 'weight': 1},
#  {'source': 'avid D. Ha', 'target': 'ames Alg', 'weight': 1},
#  {'source': 'avid D. Ha', 'target': 'im Handl', 'weight': 1},
#  {'source': 'avid D. Ha', 'target': 'orman Fergus', 'weight': 1},
#  {'source': 'avid D. Ha', 'target': 'aul Satterfie', 'weight': 1},
#  {'source': 'avid D. Ha', 'target': 'amuel Armstro', 'weight': 1},
#  {'source': 'avid D. Ha', 'target': '. H', 'weight': 1},
#  {'source': 'avid D. Ha', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'ord Bee', 'target': 'amilton Lus', 'weight': 1},
#  {'source': 'ord Bee', 'target': 'ames Alg', 'weight': 1},
#  {'source': 'ord Bee', 'target': 'im Handl', 'weight': 1},
#  {'source': 'ord Bee', 'target': 'orman Fergus', 'weight': 1},
#  {'source': 'ord Bee', 'target': 'aul Satterfie', 'weight': 1},
#  {'source': 'ord Bee', 'target': 'amuel Armstro', 'weight': 1},
#  {'source': 'ord Bee', 'target': '. H', 'weight': 1},
#  {'source': 'ord Bee', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'amilton Lus', 'target': 'ames Alg', 'weight': 1},
#  {'source': 'amilton Lus', 'target': 'im Handl', 'weight': 1},
#  {'source': 'amilton Lus', 'target': 'aul Satterfie', 'weight': 1},
#  {'source': 'amilton Lus', 'target': 'amuel Armstro', 'weight': 1},
#  {'source': 'ames Alg', 'target': 'im Handl', 'weight': 1},
#  {'source': 'ames Alg', 'target': 'orman Fergus', 'weight': 1},
#  {'source': 'ames Alg', 'target': 'aul Satterfie', 'weight': 2},
#  {'source': 'ames Alg', 'target': 'amuel Armstro', 'weight': 2},
#  {'source': 'ames Alg', 'target': '. H', 'weight': 1},
#  {'source': 'ames Alg', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'im Handl', 'target': 'orman Fergus', 'weight': 1},
#  {'source': 'im Handl', 'target': 'aul Satterfie', 'weight': 1},
#  {'source': 'im Handl', 'target': 'amuel Armstro', 'weight': 1},
#  {'source': 'im Handl', 'target': '. H', 'weight': 1},
#  {'source': 'im Handl', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'orman Fergus', 'target': 'aul Satterfie', 'weight': 1},
#  {'source': 'orman Fergus', 'target': 'amuel Armstro', 'weight': 2},
#  {'source': 'aul Satterfie', 'target': 'amuel Armstro', 'weight': 2},
#  {'source': 'aul Satterfie', 'target': '. H', 'weight': 1},
#  {'source': 'aul Satterfie', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'amuel Armstro', 'target': '. H', 'weight': 1},
#  {'source': 'amuel Armstro', 'target': 'ilfred Jacks', 'weight': 2},
#  {'source': 'en Sharpste', 'target': 'equence director', 'weight': 1},
#  {'source': 'en Sharpste', 'target': 'upervising directo', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'equence director', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'upervising directo', 'weight': 1},
#  {'source': 'ack Kinn', 'target': 'amuel Armstro', 'weight': 1},
#  {'source': 'ack Kinn', 'target': 'equence director', 'weight': 1},
#  {'source': 'ack Kinn', 'target': 'upervising directo', 'weight': 1},
#  {'source': 'orman Fergus', 'target': 'equence director', 'weight': 1},
#  {'source': 'orman Fergus', 'target': 'upervising directo', 'weight': 1},
#  {'source': 'amuel Armstro', 'target': 'equence director', 'weight': 1},
#  {'source': 'amuel Armstro', 'target': 'upervising directo', 'weight': 1},
#  {'source': 'equence director', 'target': 'upervising directo', 'weight': 1},
#  {'source': 'equence director', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'upervising directo', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'avid Ha', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'raham He', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'orman Wrig', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'equence directo', 'weight': 1},
#  {'source': 'ill Rober', 'target': 'upervising direct', 'weight': 1},
#  {'source': 'avid Ha', 'target': 'raham He', 'weight': 1},
#  {'source': 'avid Ha', 'target': 'ames Alg', 'weight': 1},
#  {'source': 'avid Ha', 'target': 'orman Wrig', 'weight': 1},
#  {'source': 'avid Ha', 'target': 'aul Satterfie', 'weight': 1},
#  {'source': 'avid Ha', 'target': 'amuel Armstro', 'weight': 1},
#  {'source': 'avid Ha', 'target': 'equence directo', 'weight': 1},
#  {'source': 'avid Ha', 'target': 'upervising direct', 'weight': 1},
#  {'source': 'raham He', 'target': 'ames Alg', 'weight': 1},
#  {'source': 'raham He', 'target': 'orman Wrig', 'weight': 1},
#  {'source': 'raham He', 'target': 'aul Satterfie', 'weight': 1},
#  {'source': 'raham He', 'target': 'amuel Armstro', 'weight': 1},
#  {'source': 'raham He', 'target': 'equence directo', 'weight': 1},
#  {'source': 'raham He', 'target': 'upervising direct', 'weight': 1},
#  {'source': 'ames Alg', 'target': 'orman Wrig', 'weight': 1},
#  {'source': 'ames Alg', 'target': 'equence directo', 'weight': 1},
#  {'source': 'ames Alg', 'target': 'upervising direct', 'weight': 1},
#  {'source': 'orman Wrig', 'target': 'aul Satterfie', 'weight': 1},
#  {'source': 'orman Wrig', 'target': 'amuel Armstro', 'weight': 1},
#  {'source': 'orman Wrig', 'target': 'equence directo', 'weight': 1},
#  {'source': 'orman Wrig', 'target': 'upervising direct', 'weight': 1},
#  {'source': 'aul Satterfie', 'target': 'equence directo', 'weight': 1},
#  {'source': 'aul Satterfie', 'target': 'upervising direct', 'weight': 1},
#  {'source': 'amuel Armstro', 'target': 'equence directo', 'weight': 1},
#  {'source': 'amuel Armstro', 'target': 'upervising direct', 'weight': 1},
#  {'source': 'equence directo', 'target': 'upervising direct', 'weight': 1},
#  {'source': 'lyde Geroni', 'target': 'amilton Lus', 'weight': 7},
#  {'source': 'lyde Geroni', 'target': 'ack Kinn', 'weight': 2},
#  {'source': 'lyde Geroni', 'target': 'oshua Mead', 'weight': 1},
#  {'source': 'lyde Geroni', 'target': 'obert Corma', 'weight': 1},
#  {'source': 'amilton Lus', 'target': 'oshua Mead', 'weight': 1},
#  {'source': 'amilton Lus', 'target': 'obert Corma', 'weight': 1},
#  {'source': 'ack Kinn', 'target': 'oshua Mead', 'weight': 1},
#  {'source': 'ack Kinn', 'target': 'obert Corma', 'weight': 1},
#  {'source': 'oshua Mead', 'target': 'obert Corma', 'weight': 1},
#  {'source': 'nimatio', 'target': 'arve Fost', 'weight': 1},
#  {'source': 'nimatio', 'target': 'ive actio', 'weight': 1},
#  {'source': 'nimatio', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'arve Fost', 'target': 'ive actio', 'weight': 1},
#  {'source': 'arve Fost', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'ive actio', 'target': 'ilfred Jacks', 'weight': 1},
#  {'source': 'lyde Geroni', 'target': 'ilfred Jacks', 'weight': 5},
#  {'source': 'lyde Geronimi (supervisin', 'target': 'ric Lars', 'weight': 1},
#  {'source': 'lyde Geronimi (supervisin', 'target': 'es Cla', 'weight': 1},
#  {'source': 'lyde Geronimi (supervisin',
#   'target': 'olfgang Reitherm',
#   'weight': 1},
#  {'source': 'ric Lars', 'target': 'es Cla', 'weight': 1},
#  {'source': 'ric Lars', 'target': 'olfgang Reitherm', 'weight': 1},
#  {'source': 'es Cla', 'target': 'olfgang Reitherm', 'weight': 1},
#  {'source': 'ohn McKims', 'target': 'en Annak', 'weight': 1},
#  {'source': 'lyde Geroni', 'target': 'olfgang Reitherm', 'weight': 1},
#  {'source': 'amilton Lus', 'target': 'olfgang Reitherm', 'weight': 1},
#  {'source': 'rt Steve', 'target': 'ohn Lounsbe', 'weight': 1},
#  {'source': 'rt Steve', 'target': 'olfgang Reitherm', 'weight': 1},
#  {'source': 'ohn Lounsbe', 'target': 'olfgang Reitherm', 'weight': 1},
#  {'source': 'rt Steve', 'target': 'ichard Ri', 'weight': 1},
#  {'source': 'rt Steve', 'target': 'ed Berm', 'weight': 1},
#  {'source': 'ichard Ri', 'target': 'ed Berm', 'weight': 2},
#  {'source': 'urny Mattins', 'target': 'ave Michen', 'weight': 1},
#  {'source': 'urny Mattins', 'target': 'ohn Musk', 'weight': 1},
#  {'source': 'urny Mattins', 'target': 'on Clemen', 'weight': 1},
#  {'source': 'ave Michen', 'target': 'ohn Musk', 'weight': 1},
#  {'source': 'ave Michen', 'target': 'on Clemen', 'weight': 1},
#  {'source': 'ohn Musk', 'target': 'on Clemen', 'weight': 6},
#  {'source': 'ary Trousda', 'target': 'irk Wi', 'weight': 3},
#  {'source': 'ob Minko', 'target': 'oger Alle', 'weight': 1},
#  {'source': 'ric Goldbe', 'target': 'ike Gabri', 'weight': 1},
#  {'source': 'arry Co', 'target': 'ony Bancro', 'weight': 1},
#  {'source': 'hris Bu', 'target': 'evin Li', 'weight': 1},
#  {'source': 'on Ha', 'target': 'ric Goldbe', 'weight': 2},
#  {'source': 'on Ha', 'target': 'rancis Gleb', 'weight': 2},
#  {'source': 'on Ha', 'target': 'endel But', 'weight': 2},
#  {'source': 'on Ha', 'target': 'ames Alg', 'weight': 2},
#  {'source': 'on Ha', 'target': 'aul and Gaëtan Briz', 'weight': 2},
#  {'source': 'on Ha', 'target': 'ixote Hu', 'weight': 2},
#  {'source': 'ric Goldbe', 'target': 'rancis Gleb', 'weight': 2},
#  {'source': 'ric Goldbe', 'target': 'endel But', 'weight': 2},
#  {'source': 'ric Goldbe', 'target': 'ames Alg', 'weight': 2},
#  {'source': 'ric Goldbe', 'target': 'aul and Gaëtan Briz', 'weight': 2},
#  {'source': 'ric Goldbe', 'target': 'ixote Hu', 'weight': 2},
#  {'source': 'rancis Gleb', 'target': 'endel But', 'weight': 2},
#  {'source': 'rancis Gleb', 'target': 'ames Alg', 'weight': 2},
#  {'source': 'rancis Gleb', 'target': 'aul and Gaëtan Briz', 'weight': 2},
#  {'source': 'rancis Gleb', 'target': 'ixote Hu', 'weight': 2},
#  {'source': 'endel But', 'target': 'ames Alg', 'weight': 2},
#  {'source': 'endel But', 'target': 'aul and Gaëtan Briz', 'weight': 2},
#  {'source': 'endel But', 'target': 'ixote Hu', 'weight': 2},
#  {'source': 'ames Alg', 'target': 'aul and Gaëtan Briz', 'weight': 2},
#  {'source': 'ames Alg', 'target': 'ixote Hu', 'weight': 2},
#  {'source': 'aul and Gaëtan Briz', 'target': 'ixote Hu', 'weight': 2},
#  {'source': 'ric Leight', 'target': 'alph Zond', 'weight': 1},
#  {'source': 'hris Sande', 'target': 'ean DeBlo', 'weight': 1},
#  {'source': 'aron Blai', 'target': 'obert Walk', 'weight': 1},
#  {'source': 'ohn Sanfo', 'target': 'ill Fi', 'weight': 1},
#  {'source': 'lastair Fothergi', 'target': 'ark Linfie', 'weight': 3},
#  {'source': 'yron Howa', 'target': 'hris Willia', 'weight': 1},
#  {'source': 'co-directo', 'target': 'acques Cluza', 'weight': 1},
#  {'source': 'co-directo', 'target': 'acques Perr', 'weight': 1},
#  {'source': 'acques Cluza', 'target': 'acques Perr', 'weight': 1},
#  {'source': 'yron Howa', 'target': 'athan Gre', 'weight': 1},
#  {'source': 'on Ha', 'target': 'tephen J. Anders', 'weight': 1},
#  {'source': 'lastair Fothergi', 'target': 'eith Schol', 'weight': 2},
#  {'source': 'renda Chapm', 'target': 'ark Andre', 'weight': 1},
#  {'source': 'hris Bu', 'target': 'ennifer L', 'weight': 2},
#  {'source': 'hris Willia', 'target': 'on Ha', 'weight': 1},
#  {'source': 'yron Howa', 'target': 'ich Moo', 'weight': 1},
#  {'source': 'spen Sandbe', 'target': 'oachim Rønni', 'weight': 1},
#  {'source': 'oe Johnst', 'target': 'asse Hallstr', 'weight': 1},
#  {'source': 'hil Johnst', 'target': 'ich Moo', 'weight': 1}]

# %%
import json

directors = {"nodes": director_nodes, "links":director_links}

with open('directors.json', 'w') as json_file:
  json.dump(directors, json_file)

# %%
producers_nodes = [{"name":key,"count":producers[key]} for key in producers]
counter=collections.Counter(producers_edges)
producers_links = [{"source":key[0],"target":key[1],"weight":counter[key]} for key in counter]

# %%
producers = {"nodes": producers_nodes, "links":producers_links}

with open('producers.json', 'w') as json_file:
  json.dump(producers, json_file)

# %%
music_directors_nodes = [{"name":key,"count":music_directors[key]} for key in music_directors]
counter=collections.Counter(music_directors_edges)
music_directors_links = [{"source":key[0],"target":key[1],"weight":counter[key]} for key in counter]

music_directors = {"nodes": music_directors_nodes, "links":music_directors_links}

with open('music_directors.json', 'w') as json_file:
  json.dump(music_directors, json_file)
