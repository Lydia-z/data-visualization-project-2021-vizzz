# %% [markdown]
# # Data Clean Up and Exploratory Data Analysis

# %% [markdown]
# The main goal of this notebook is to get a global view of the four dataset we found. In order to get as much useful information as possible, we will then merge the four dataset and get one clean data. In the later work, the clean dataset will be the only dataset we use.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Explore the first dataset

# %%
# data1 comes from https://www.kaggle.com/sooaaib/walt-disney-movies?select=disney_movies.csv
# read data1
data1 = pd.read_csv('./data1.csv', error_bad_lines=False)
print('size of the first dataset is ', data1.shape)
data1.head()
# Out:
# size of the first dataset is  (437, 36)
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#                                         Release date  \
# 0                                   ['May 19, 1937']
# 1  ['December 21, 1937 ( Carthay Circle Theatre ,...
# 2  ['February 7, 1940 ( Center Theatre )', 'Febru...
# 3                              ['November 13, 1940']
# 4                                  ['June 20, 1941']
#
#                            Running time        Country Language  \
# 0  41 minutes (74 minutes 1966 release)  United States  English
# 1                            83 minutes  United States  English
# 2                            88 minutes  United States  English
# 3                           126 minutes  United States  English
# 4                            74 minutes  United States  English
#
#                      Box office  Running time (int)  Budget (float)  ...  \
# 0                       $45.472                41.0             NaN  ...
# 1                  $418 million                83.0       1490000.0  ...
# 2                  $164 million                88.0       2600000.0  ...
# 3           $76.4–$83.3 million               126.0       2280000.0  ...
# 4  $960,000 (worldwide rentals)                74.0        600000.0  ...
#
#     Narrated by   Cinematography        Edited by Screenplay by  \
# 0           NaN              NaN              NaN           NaN
# 1           NaN              NaN              NaN           NaN
# 2           NaN              NaN              NaN           NaN
# 3  Deems Taylor  James Wong Howe              NaN           NaN
# 4           NaN     Bert Giennon  Paul Weatherwax           NaN
#
#   Production companies  Japanese Hepburn Adaptation by Traditional Simplified
# 0                  NaN       NaN     NaN           NaN         NaN        NaN
# 1                  NaN       NaN     NaN           NaN         NaN        NaN
# 2                  NaN       NaN     NaN           NaN         NaN        NaN
# 3                  NaN       NaN     NaN           NaN         NaN        NaN
# 4                  NaN       NaN     NaN           NaN         NaN        NaN
#
# [5 rows x 36 columns]

# %%
print("Number of unique films: ", len(data1.title.unique()))
print("Number of unique release date: ", len(data1['Release date'].unique()))
# Out:
# Number of unique films:  424
# Number of unique release date:  433

# %% [markdown]
# Among the 437 films, unique films take up 424, but the unique number of release date is different. Therefore, we deduce that there may be films that are remade.

# %%
data1['title'].value_counts()
# Out:
# The Lion King                      2
# Lady and the Tramp                 2
# Freaky Friday                      2
# Aladdin                            2
# The Shaggy Dog                     2
#                                   ..
# The Country Bears                  1
# Toy Story 2                        1
# Toy Story                          1
# Run, Cougar, Run                   1
# Alice Through the Looking Glass    1
# Name: title, Length: 424, dtype: int64

# %%
data1.loc[data1['title'] == 'Freaky Friday']
# Out:
#      Unnamed: 0          title                      Production company  \
# 127         127  Freaky Friday                 Walt Disney Productions
# 265         265  Freaky Friday  ['Walt Disney Pictures', 'Gunn Films']
#
#                                           Release date Running time  \
# 127                              ['December 17, 1976']   95 minutes
# 265  ['August 4, 2003 ( Los Angeles )', 'August 6, ...   97 minutes
#
#            Country Language      Box office  Running time (int)  \
# 127  United States  English     $36 million                95.0
# 265  United States  English  $160.8 million                97.0
#
#      Budget (float)  ...  Narrated by      Cinematography         Edited by  \
# 127       5000000.0  ...          NaN  Charles F. Wheeler  Cotton Warburton
# 265      26000000.0  ...          NaN         Oliver Wood       Bruce Green
#
#                         Screenplay by Production companies  Japanese Hepburn  \
# 127                      Mary Rodgers                  NaN       NaN     NaN
# 265  ['Heather Hach', 'Leslie Dixon']                  NaN       NaN     NaN
#
#     Adaptation by Traditional Simplified
# 127           NaN         NaN        NaN
# 265           NaN         NaN        NaN
#
# [2 rows x 36 columns]

# %% [markdown]
# We first consider different versions of the same film as different ones. There are 36 features in total in data1, but we are interested in only part of those features, select the useful features.

# %%
list(data1.columns)
# Out:
# ['Unnamed: 0',
#  'title',
#  'Production company',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Box office',
#  'Running time (int)',
#  'Budget (float)',
#  'Box office (float)',
#  'Release date (datetime)',
#  'imdb_rating',
#  'imdb_votes',
#  'imdb_id',
#  'metascore',
#  'rotten_tomatoes',
#  'Directed by',
#  'Produced by',
#  'Written by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Distributed by',
#  'Budget',
#  'Story by',
#  'Narrated by',
#  'Cinematography',
#  'Edited by',
#  'Screenplay by',
#  'Production companies',
#  'Japanese',
#  'Hepburn',
#  'Adaptation by',
#  'Traditional',
#  'Simplified']

# %%
# select the features are useful to our project
data1_select = data1[['title',
 'Running time (int)',
 'Budget (float)',
 'Box office (float)',
 'Release date (datetime)',
 'imdb_rating',
 'metascore',
 'rotten_tomatoes',
 'Directed by',
 'Produced by',
 'Music by',
 'Distributed by']].rename(columns={'Running time (int)': 'Running time', 
                                    'Budget (float)': 'Budget',
                                    'Box office (float)': 'Box office',
                                    'Release date (datetime)': 'Release date',
                                    'imdb_rating': 'imdb'})
data1_select.head()
# Out:
#                              title  Running time     Budget    Box office  \
# 0          Academy Award Review of          41.0        NaN  4.547200e+01
# 1  Snow White and the Seven Dwarfs          83.0  1490000.0  4.180000e+08
# 2                        Pinocchio          88.0  2600000.0  1.640000e+08
# 3                         Fantasia         126.0  2280000.0  8.330000e+07
# 4             The Reluctant Dragon          74.0   600000.0  9.600000e+05
#
#   Release date  imdb  metascore rotten_tomatoes  \
# 0   1937-05-19   7.2        7.2             NaN
# 1   1937-12-21   7.6        7.6             NaN
# 2   1940-02-07   7.4        7.4            100%
# 3   1940-11-13   7.8        7.8             95%
# 4   1941-06-20   6.9        6.9             67%
#
#                                          Directed by  \
# 0                                                NaN
# 1  ['David Hand (supervising)', 'William Cottrell...
# 2  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4  ['Alfred Werker', '(live action)', 'Hamilton L...
#
#                          Produced by  \
# 0                                NaN
# 1                        Walt Disney
# 2                        Walt Disney
# 3  ['Walt Disney', 'Ben Sharpsteen']
# 4                        Walt Disney
#
#                                             Music by  \
# 0                                                NaN
# 1  ['Frank Churchill', 'Paul Smith', 'Leigh Harli...
# 2                 ['Leigh Harline', 'Paul J. Smith']
# 3                                        See program
# 4                 ['Frank Churchill', 'Larry Morey']
#
#                                       Distributed by
# 0                                                NaN
# 1                                 RKO Radio Pictures
# 2                                 RKO Radio Pictures
# 3  ['Walt Disney Productions', 'RKO Radio Pictures']
# 4                                 RKO Radio Pictures

# %% [markdown]
# ## Explore the second dataset

# %%
# read data2 from https://www.kaggle.com/dikshabhati2002/walt-disney-movies
data2 = pd.read_csv('./data2.csv', error_bad_lines=False)
print('size of the second dataset is ', data2.shape)
data2.head()
# Out:
# size of the second dataset is  (444, 21)
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#          Country Language  Running time     Budget    Box office Release date  \
# 0  United States  English          41.0        NaN  4.547200e+01   1937-05-19
# 1  United States  English          83.0  1490000.0  4.180000e+08   1937-12-21
# 2  United States  English          88.0  2600000.0  1.640000e+08   1940-02-07
# 3  United States  English         126.0  2280000.0  8.330000e+07   1940-11-13
# 4  United States  English          74.0   600000.0  9.600000e+05   1941-06-20
#
#    imdb  ...  rotten_tomatoes  \
# 0   7.2  ...              NaN
# 1   7.6  ...              NaN
# 2   7.4  ...              73%
# 3   7.7  ...              95%
# 4   6.9  ...              68%
#
#                                          Directed by  \
# 0                                                NaN
# 1  ['David Hand (supervising)', 'William Cottrell...
# 2  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4  ['Alfred Werker', '(live action)', 'Hamilton L...
#
#                          Produced by  \
# 0                                NaN
# 1                        Walt Disney
# 2                        Walt Disney
# 3  ['Walt Disney', 'Ben Sharpsteen']
# 4                        Walt Disney
#
#                                             Based on  \
# 0                                                NaN
# 1         ['Snow White', 'by The', 'Brothers Grimm']
# 2  ['The Adventures of Pinocchio', 'by', 'Carlo C...
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  \
# 0                                                NaN
# 1  ['Adriana Caselotti', 'Lucille La Verne', 'Har...
# 2  ['Cliff Edwards', 'Dickie Jones', 'Christian R...
# 3              ['Leopold Stokowski', 'Deems Taylor']
# 4  ['Robert Benchley', 'Frances Gifford', 'Buddy ...
#
#                                             Music by      Distributed by  \
# 0                                                NaN                 NaN
# 1  ['Frank Churchill', 'Paul Smith', 'Leigh Harli...  RKO Radio Pictures
# 2                 ['Leigh Harline', 'Paul J. Smith']  RKO Radio Pictures
# 3                                        See program  RKO Radio Pictures
# 4                 ['Frank Churchill', 'Larry Morey']  RKO Radio Pictures
#
#     Cinematography        Edited by Screenplay by
# 0              NaN              NaN           NaN
# 1              NaN              NaN           NaN
# 2              NaN              NaN           NaN
# 3  James Wong Howe              NaN           NaN
# 4     Bert Giennon  Paul Weatherwax           NaN
#
# [5 rows x 21 columns]

# %%
print("Number of unique films: ", len(data2.title.unique()))
print("Number of unique release date: ", len(data2['Release date'].unique()))
data1['title'].value_counts()
# Out:
# Number of unique films:  431
# Number of unique release date:  430
# The Lion King                      2
# Lady and the Tramp                 2
# Freaky Friday                      2
# Aladdin                            2
# The Shaggy Dog                     2
#                                   ..
# The Country Bears                  1
# Toy Story 2                        1
# Toy Story                          1
# Run, Cougar, Run                   1
# Alice Through the Looking Glass    1
# Name: title, Length: 424, dtype: int64

# %%
data2.loc[data2['title'] == 'Freaky Friday']
# Out:
#      Unnamed: 0          title                      Production company  \
# 127         127  Freaky Friday                 Walt Disney Productions
# 265         265  Freaky Friday  ['Walt Disney Pictures', 'Gunn Films']
#
#            Country Language  Running time      Budget   Box office  \
# 127  United States  English          95.0   5000000.0   36000000.0
# 265  United States  English          97.0  26000000.0  160800000.0
#
#     Release date  imdb  ...  rotten_tomatoes  Directed by  Produced by  \
# 127   1976-12-20   6.2  ...              88%  Gary Nelson   Ron Miller
# 265   2003-08-04   6.2  ...              88%  Mark Waters  Andrew Gunn
#
#                                     Based on  \
# 127     ['Freaky Friday', 'by Mary Rodgers']
# 265  ['Freaky Friday', 'by', 'Mary Rodgers']
#
#                                               Starring       Music by  \
# 127   ['Jodie Foster', 'Barbara Harris', 'John Astin']  Johnny Mandel
# 265  ['Jamie Lee Curtis', 'Lindsay Lohan', 'Harold ...     Rolfe Kent
#
#                Distributed by      Cinematography         Edited by  \
# 127  Buena Vista Distribution  Charles F. Wheeler  Cotton Warburton
# 265      Buena Vista Pictures         Oliver Wood       Bruce Green
#
#                         Screenplay by
# 127                      Mary Rodgers
# 265  ['Heather Hach', 'Leslie Dixon']
#
# [2 rows x 21 columns]

# %%
list(data2.columns)
# Out:
# ['Unnamed: 0',
#  'title',
#  'Production company',
#  'Country',
#  'Language',
#  'Running time',
#  'Budget',
#  'Box office',
#  'Release date',
#  'imdb',
#  'metascore',
#  'rotten_tomatoes',
#  'Directed by',
#  'Produced by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Distributed by',
#  'Cinematography',
#  'Edited by',
#  'Screenplay by']

# %%
# select features
data2_select = data2[['title',
 'Running time',
 'Budget',
 'Box office',
 'Release date',
 'imdb',
 'metascore',
 'rotten_tomatoes',
 'Directed by',
 'Produced by',
 'Music by',
 'Distributed by']]
data2_select.head()
# Out:
#                              title  Running time     Budget    Box office  \
# 0          Academy Award Review of          41.0        NaN  4.547200e+01
# 1  Snow White and the Seven Dwarfs          83.0  1490000.0  4.180000e+08
# 2                        Pinocchio          88.0  2600000.0  1.640000e+08
# 3                         Fantasia         126.0  2280000.0  8.330000e+07
# 4             The Reluctant Dragon          74.0   600000.0  9.600000e+05
#
#   Release date  imdb  metascore rotten_tomatoes  \
# 0   1937-05-19   7.2        NaN             NaN
# 1   1937-12-21   7.6       95.0             NaN
# 2   1940-02-07   7.4       99.0             73%
# 3   1940-11-13   7.7       96.0             95%
# 4   1941-06-20   6.9        NaN             68%
#
#                                          Directed by  \
# 0                                                NaN
# 1  ['David Hand (supervising)', 'William Cottrell...
# 2  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4  ['Alfred Werker', '(live action)', 'Hamilton L...
#
#                          Produced by  \
# 0                                NaN
# 1                        Walt Disney
# 2                        Walt Disney
# 3  ['Walt Disney', 'Ben Sharpsteen']
# 4                        Walt Disney
#
#                                             Music by      Distributed by
# 0                                                NaN                 NaN
# 1  ['Frank Churchill', 'Paul Smith', 'Leigh Harli...  RKO Radio Pictures
# 2                 ['Leigh Harline', 'Paul J. Smith']  RKO Radio Pictures
# 3                                        See program  RKO Radio Pictures
# 4                 ['Frank Churchill', 'Larry Morey']  RKO Radio Pictures

# %% [markdown]
# ## Explore the third dataset

# %%
# read data3 from https://www.kaggle.com/therealsampat/disney-movies-dataset
data3 = pd.read_csv('./data3.csv', error_bad_lines=False)
print('size of the fourth dataset is ', data3.shape)
data3.head()
# Out:
# size of the fourth dataset is  (432, 32)
#    Unnamed: 0                            title       Production company  \
# 0           0          Academy Award Review of  Walt Disney Productions
# 1           1  Snow White and the Seven Dwarfs  Walt Disney Productions
# 2           2                        Pinocchio  Walt Disney Productions
# 3           3                         Fantasia  Walt Disney Productions
# 4           4             The Reluctant Dragon  Walt Disney Productions
#
#                                         Release date  \
# 0                                   ['May 19, 1937']
# 1  ['December 21, 1937 ( Carthay Circle Theatre ,...
# 2  ['February 7, 1940 ( Center Theatre )', 'Febru...
# 3                              ['November 13, 1940']
# 4                                  ['June 20, 1941']
#
#                            Running time        Country Language  \
# 0  41 minutes (74 minutes 1966 release)  United States  English
# 1                            83 minutes  United States  English
# 2                            88 minutes  United States  English
# 3                           126 minutes  United States  English
# 4                            74 minutes  United States  English
#
#    Running time (int)  Budget (float)  Box office (float)  ...  \
# 0                41.0             NaN                 NaN  ...
# 1                83.0       1490000.0         418000000.0  ...
# 2                88.0       2600000.0         164000000.0  ...
# 3               126.0       2280000.0          83300000.0  ...
# 4                74.0        600000.0            960000.0  ...
#
#                      Box office  \
# 0                           NaN
# 1                  $418 million
# 2                  $164 million
# 3           $76.4–$83.3 million
# 4  $960,000 (worldwide rentals)
#
#                                             Story by   Narrated by  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2  ['Ted Sears', 'Otto Englander', 'Webb Smith', ...           NaN
# 3                       ['Joe Grant', 'Dick Huemer']  Deems Taylor
# 4                                                NaN           NaN
#
#     Cinematography        Edited by Screenplay by Production companies  \
# 0              NaN              NaN           NaN                  NaN
# 1              NaN              NaN           NaN                  NaN
# 2              NaN              NaN           NaN                  NaN
# 3  James Wong Howe              NaN           NaN                  NaN
# 4     Bert Giennon  Paul Weatherwax           NaN                  NaN
#
#   Adaptation by Traditional Simplified
# 0           NaN         NaN        NaN
# 1           NaN         NaN        NaN
# 2           NaN         NaN        NaN
# 3           NaN         NaN        NaN
# 4           NaN         NaN        NaN
#
# [5 rows x 32 columns]

# %%
list(data3.columns)
# Out:
# ['Unnamed: 0',
#  'title',
#  'Production company',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Running time (int)',
#  'Budget (float)',
#  'Box office (float)',
#  'Release date (datetime)',
#  'imdb',
#  'metascore',
#  'rotten_tomatoes',
#  'Directed by',
#  'Produced by',
#  'Written by',
#  'Based on',
#  'Starring',
#  'Music by',
#  'Distributed by',
#  'Budget',
#  'Box office',
#  'Story by',
#  'Narrated by',
#  'Cinematography',
#  'Edited by',
#  'Screenplay by',
#  'Production companies',
#  'Adaptation by',
#  'Traditional',
#  'Simplified']

# %%
# select features
data3_select = data3[['title',
 'Running time (int)',
 'Budget (float)',
 'Box office (float)',
 'Release date (datetime)',
 'imdb',
 'metascore',
 'rotten_tomatoes',
 'Directed by',
 'Produced by',
 'Music by',
 'Distributed by',]].rename(columns={'Running time (int)': 'Running time', 
                                    'Budget (float)': 'Budget',
                                    'Box office (float)': 'Box office',
                                    'Release date (datetime)': 'Release date'})
data3_select.head()
# Out:
#                              title  Running time     Budget   Box office  \
# 0          Academy Award Review of          41.0        NaN          NaN
# 1  Snow White and the Seven Dwarfs          83.0  1490000.0  418000000.0
# 2                        Pinocchio          88.0  2600000.0  164000000.0
# 3                         Fantasia         126.0  2280000.0   83300000.0
# 4             The Reluctant Dragon          74.0   600000.0     960000.0
#
#   Release date  imdb  metascore rotten_tomatoes  \
# 0   1937-05-19   7.2        NaN             NaN
# 1   1937-12-21   7.6       95.0             NaN
# 2   1940-02-07   7.4       99.0            100%
# 3   1940-11-13   7.8       96.0             95%
# 4   1941-06-20   6.9        NaN             67%
#
#                                          Directed by  \
# 0                                                NaN
# 1  ['David Hand (supervising)', 'William Cottrell...
# 2  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4  ['Alfred Werker', '(live action)', 'Hamilton L...
#
#                          Produced by  \
# 0                                NaN
# 1                        Walt Disney
# 2                        Walt Disney
# 3  ['Walt Disney', 'Ben Sharpsteen']
# 4                        Walt Disney
#
#                                             Music by  \
# 0                                                NaN
# 1  ['Frank Churchill', 'Paul Smith', 'Leigh Harli...
# 2                 ['Leigh Harline', 'Paul J. Smith']
# 3                                        See program
# 4                 ['Frank Churchill', 'Larry Morey']
#
#                                       Distributed by
# 0                                                NaN
# 1                                 RKO Radio Pictures
# 2                                 RKO Radio Pictures
# 3  ['Walt Disney Productions', 'RKO Radio Pictures']
# 4                                 RKO Radio Pictures

# %% [markdown]
# ## Merge the selected dataset

# %% [markdown]
# We wish to get as many useful data as possible, therefore we merge the three dataset and get the final dataset. In the later part of this project, we will make use of the final dataset only.

# %%
data_temp = data1_select.append(data2_select, ignore_index=True)

# drop duplicated movies by title and releasse date
data_temp.drop_duplicates(subset =['title', 'Release date'], keep = 'last', inplace = True)
data_temp = data_temp.reset_index(drop=True)

# %%
data_final = data_temp.append(data3_select, ignore_index=True)

# drop duplicated movies by title and releasse date
data_final.drop_duplicates(subset =['title', 'Release date'], keep = 'last', inplace = True)
data_final = data_final.reset_index(drop=True)

# %%
# reorder films based on release date
data_final = data_final.sort_values(by='Release date', ascending=1)
data_final = data_final.reset_index(drop=True)
data_final
# Out:
#                                               title  Running time  \
# 0                           Academy Award Review of          41.0
# 1                   Snow White and the Seven Dwarfs          83.0
# 2                                         Pinocchio          88.0
# 3                                          Fantasia         126.0
# 4                              The Reluctant Dragon          74.0
# ..                                              ...           ...
# 471                             Night at the Museum         306.0
# 472                              The Straight Story         112.0
# 473  Lilly the Witch: The Dragon and the Magic Book           NaN
# 474                                 Walt & El Grupo           NaN
# 475                             The Book of Masters         101.0
#
#           Budget    Box office Release date  imdb  metascore rotten_tomatoes  \
# 0            NaN           NaN   1937-05-19   7.2        NaN             NaN
# 1      1490000.0  4.180000e+08   1937-12-21   7.6       95.0             NaN
# 2      2600000.0  1.640000e+08   1940-02-07   7.4       99.0            100%
# 3      2280000.0  8.330000e+07   1940-11-13   7.8       96.0             95%
# 4       600000.0  9.600000e+05   1941-06-20   6.9        NaN             67%
# ..           ...           ...          ...   ...        ...             ...
# 471  387000000.0  1.310000e+09          NaN   6.4       48.0             43%
# 472   10000000.0  6.200000e+06          NaN   8.0       86.0             95%
# 473          NaN           NaN          NaN   5.2        NaN             27%
# 474          NaN           NaN          NaN   6.3       55.0             59%
# 475    8000000.0  1.130000e+07          NaN   NaN        NaN             NaN
#
#                                            Directed by  \
# 0                                                  NaN
# 1    ['David Hand (supervising)', 'William Cottrell...
# 2    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 3    ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 4    ['Alfred Werker', '(live action)', 'Hamilton L...
# ..                                                 ...
# 471                                         Shawn Levy
# 472                                        David Lynch
# 473                                  Stefan Ruzowitzky
# 474                                    Theodore Thomas
# 475                                   Vadim Sokolovsky
#
#                                            Produced by  \
# 0                                                  NaN
# 1                                          Walt Disney
# 2                                          Walt Disney
# 3                    ['Walt Disney', 'Ben Sharpsteen']
# 4                                          Walt Disney
# ..                                                 ...
# 471  ['Shawn Levy', 'Chris Columbus', 'Michael Barn...
# 472  ['Mary Sweeney', 'Neal Edelstein', 'Alain Sarde']
# 473                                                NaN
# 474                                                NaN
# 475  ['Leonid Vereshchagin,', 'Marina Zhigalov-Ozkan']
#
#                                               Music by  \
# 0                                                  NaN
# 1    ['Frank Churchill', 'Paul Smith', 'Leigh Harli...
# 2                   ['Leigh Harline', 'Paul J. Smith']
# 3                                          See program
# 4                   ['Frank Churchill', 'Larry Morey']
# ..                                                 ...
# 471                                     Alan Silvestri
# 472                                 Angelo Badalamenti
# 473                                       Ian Honeyman
# 474                                                NaN
# 475                                     Yuri Poteyenko
#
#                                         Distributed by
# 0                                                  NaN
# 1                                   RKO Radio Pictures
# 2                                   RKO Radio Pictures
# 3    ['Walt Disney Productions', 'RKO Radio Pictures']
# 4                                   RKO Radio Pictures
# ..                                                 ...
# 471                ['20th Century Studios', 'Disney+']
# 472  ['Buena Vista Pictures', '(United States)', 'F...
# 473                                                NaN
# 474                Walt Disney Studios Motion Pictures
# 475                                                NaN
#
# [476 rows x 12 columns]

# %%
# count null value for each column
data_final.isnull().sum(axis = 0)
# Out:
# title                0
# Running time        19
# Budget             186
# Box office         105
# Release date        29
# imdb                26
# metascore          162
# rotten_tomatoes     87
# Directed by          1
# Produced by         12
# Music by            12
# Distributed by       3
# dtype: int64

# %% [markdown]
# As one can see, for the final dataset we get, there are many empty cells. We keep only the films with non-na value for the visualization purpose. But we allow the cells for Directed by, Produced by, Music by and Distributed by to be null value.

# %%
data_final = data_final[data_final['Running time'].notna()]
data_final = data_final[data_final['Budget'].notna()]
data_final = data_final[data_final['Box office'].notna()]
data_final = data_final[data_final['Release date'].notna()]
data_final = data_final[data_final['imdb'].notna()]
data_final = data_final[data_final['metascore'].notna()]
data_final = data_final[data_final['rotten_tomatoes'].notna()]

data_final = data_final.reset_index(drop=True)
data_final
# Out:
#                             title  Running time       Budget    Box office  \
# 0                       Pinocchio          88.0    2600000.0  1.640000e+08
# 1                        Fantasia         126.0    2280000.0  8.330000e+07
# 2                           Dumbo          64.0     950000.0  1.300000e+06
# 3                           Bambi          70.0     858000.0  2.674000e+08
# 4                 Make Mine Music          75.0    1350000.0  3.275000e+06
# ..                            ...           ...          ...           ...
# 219                 The Lion King         118.0  250000000.0  1.657000e+09
# 220  Maleficent: Mistress of Evil         119.0  185000000.0  4.917000e+08
# 221                     Frozen II         103.0  150000000.0  1.450000e+09
# 222                        Onward         102.0  175000000.0  1.364000e+08
# 223                         Mulan         115.0  200000000.0  5.700000e+07
#
#     Release date  imdb  metascore rotten_tomatoes  \
# 0     1940-02-07   7.4       99.0            100%
# 1     1940-11-13   7.8       96.0             95%
# 2     1941-10-23   7.2       96.0             98%
# 3     1942-08-09   7.3       91.0             90%
# 4     1946-04-20   6.3       60.0             70%
# ..           ...   ...        ...             ...
# 219   2019-07-09   8.5       88.0             93%
# 220   2019-10-18   6.6       43.0             40%
# 221   2019-11-07   6.9       64.0             77%
# 222   2020-02-21   7.4       61.0             88%
# 223   2020-03-09   7.6       71.0             86%
#
#                                            Directed by  \
# 0    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 1    ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 2    ['Supervising director:', 'Ben Sharpsteen', 'S...
# 3    ['Supervising director', 'David Hand', 'Sequen...
# 4    ['Jack Kinney', 'Clyde Geronimi', 'Hamilton Lu...
# ..                                                 ...
# 219                                        Jon Favreau
# 220                                    Joachim Rønning
# 221                     ['Chris Buck', 'Jennifer Lee']
# 222                                        Dan Scanlon
# 223                                          Niki Caro
#
#                                            Produced by  \
# 0                                          Walt Disney
# 1                    ['Walt Disney', 'Ben Sharpsteen']
# 2                                          Walt Disney
# 3                                          Walt Disney
# 4                                          Walt Disney
# ..                                                 ...
# 219  ['Jon Favreau', 'Jeffrey Silver', 'Karen Gilch...
# 220  ['Joe Roth', 'Angelina Jolie', 'Duncan Henders...
# 221                                    Peter Del Vecho
# 222                                           Kori Rae
# 223   ['Chris Bender', 'Jake Weiner', 'Jason T. Reed']
#
#                                               Music by  \
# 0                   ['Leigh Harline', 'Paul J. Smith']
# 1                                          See program
# 2                ['Frank Churchill', 'Oliver Wallace']
# 3               ['Frank Churchill', 'Edward H. Plumb']
# 4    ['Eliot Daniel', 'Ken Darby', 'Charles Wolcott...
# ..                                                 ...
# 219                                        Hans Zimmer
# 220                                      Geoff Zanelli
# 221  ['Christophe Beck', 'Robert Lopez', 'Kristen A...
# 222                    ['Mychael Danna', 'Jeff Danna']
# 223                             Harry Gregson-Williams
#
#                                         Distributed by
# 0                                   RKO Radio Pictures
# 1    ['Walt Disney Productions', 'RKO Radio Pictures']
# 2                                   RKO Radio Pictures
# 3                                   RKO Radio Pictures
# 4                             RKO Radio Pictures, Inc.
# ..                                                 ...
# 219         ['Walt Disney Studios', 'Motion Pictures']
# 220         ['Walt Disney Studios', 'Motion Pictures']
# 221         ['Walt Disney Studios', 'Motion Pictures']
# 222         ['Walt Disney Studios', 'Motion Pictures']
# 223                Walt Disney Studios Motion Pictures
#
# [224 rows x 12 columns]

# %% [markdown]
# ## Running time distribution

# %%
print("The averge running time of disney movie is ", data_final['Running time'].mean()) 

# get shortest films
data_final.loc[data_final['Running time'] == data_final['Running time'].min()]
# Out:
# The averge running time of disney movie is  99.25446428571429
#            title  Running time     Budget  Box office Release date  imdb  \
# 125  Roving Mars          40.0  1000000.0  11000000.0   2006-01-27   7.2
#
#      metascore rotten_tomatoes    Directed by  \
# 125       58.0             71%  George Butler
#
#                              Produced by                       Music by  \
# 125  ['George Butler', 'Frank Marshall']  ['Philip Glass', 'Sigur Rós']
#
#            Distributed by
# 125  Buena Vista Pictures

# %%
# get longest films
data_final.loc[data_final['Running time'] == data_final['Running time'].max()]
# Out:
#                                         title  Running time       Budget  \
# 134  Pirates of the Caribbean: At World's End         168.0  300000000.0
#
#       Box office Release date  imdb  metascore rotten_tomatoes  \
# 134  961000000.0   2007-05-19   7.1       50.0             44%
#
#         Directed by        Produced by     Music by        Distributed by
# 134  Gore Verbinski  Jerry Bruckheimer  Hans Zimmer  Buena Vista Pictures

# %%
ax = data_final['Running time'].plot.hist(bins=100, alpha=0.5)
ax.set_title("Running Time Distribution")
# Out:
# Text(0.5, 1.0, 'Running Time Distribution')

# %% [markdown]
# Most disney movies are within 2 hours.

# %% [markdown]
# ## Budget and Box Office

# %%
# get the film with the least investment
data_final.loc[data_final['Budget'] == data_final['Budget'].min()]
# Out:
#                                    title  Running time  Budget   Box office  \
# 158  Prince of Persia: The Sands of Time         116.0   150.0  336400000.0
#
#     Release date  imdb  metascore rotten_tomatoes  Directed by  \
# 158   2010-05-09   6.6       50.0             37%  Mike Newell
#
#            Produced by                Music by  \
# 158  Jerry Bruckheimer  Harry Gregson-Williams
#
#                                  Distributed by
# 158  ['Walt Disney Studios', 'Motion Pictures']

# %%
# get the film with the most investment
data_final.loc[data_final['Budget'] == data_final['Budget'].max()]
# Out:
#                                            title  Running time       Budget  \
# 169  Pirates of the Caribbean: On Stranger Tides         137.0  410600000.0
#
#        Box office Release date  imdb  metascore rotten_tomatoes   Directed by  \
# 169  1.046000e+09   2011-05-07   6.6       45.0             33%  Rob Marshall
#
#                             Produced by     Music by  \
# 169  Jerry Bruckheimer , Neal H. Moritz  Hans Zimmer
#
#                                  Distributed by
# 169  ['Walt Disney Studios', 'Motion Pictures']

# %%
# get the film with the least box office
data_final.loc[data_final['Box office'] == data_final['Box office'].min()]
# Out:
#             title  Running time      Budget  Box office Release date  imdb  \
# 28  Pete's Dragon         128.0  10000000.0        36.0   1977-11-03   6.7
#
#     metascore rotten_tomatoes  Directed by  \
# 28       71.0             88%  Don Chaffey
#
#                               Produced by      Music by  \
# 28  ['Jerome Courtland', 'Ron W. Miller']  Irwin Kostal
#
#               Distributed by
# 28  Buena Vista Distribution

# %%
# get the film with the most box office
data_final.loc[data_final['Box office'] == data_final['Box office'].max()]
# Out:
#              title  Running time       Budget    Box office Release date  \
# 219  The Lion King         118.0  250000000.0  1.657000e+09   2019-07-09
#
#      imdb  metascore rotten_tomatoes  Directed by  \
# 219   8.5       88.0             93%  Jon Favreau
#
#                                            Produced by     Music by  \
# 219  ['Jon Favreau', 'Jeffrey Silver', 'Karen Gilch...  Hans Zimmer
#
#                                  Distributed by
# 219  ['Walt Disney Studios', 'Motion Pictures']

# %%
ax = data_final['Budget'].plot.hist(bins=100, alpha=0.5)
ax.set_title("Budget Distribution")
# Out:
# Text(0.5, 1.0, 'Budget Distribution')

# %%
ax = data_final['Box office'].plot.hist(bins=100, alpha=0.5)
ax.set_title("Budget Distribution")
# Out:
# Text(0.5, 1.0, 'Budget Distribution')

# %%
ax = data_final.plot.bar(x='title', y=['Budget','Box office'], figsize=(18,10))

# %% [markdown]
# The films are arranged in time sequence, which means for the x-axis, the films on the right side are released more recently. We can observe a rough increase of the box office through time. However, for the most recent movies like Onward and Mulan, the values box office are less than the values of budget. Since these two are released in 2020, it may caused by the Covid-19 situation.

# %% [markdown]
# ## Year

# %% [markdown]
# We wish to draw the timeline of Disney movies. In this section, we will observe for each year, how many Disney movies are released.

# %%
from datetime import datetime
data_final['year'] = data_final['Release date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d').year)
data_final.head()
# Out:
#              title  Running time     Budget   Box office Release date  imdb  \
# 0        Pinocchio          88.0  2600000.0  164000000.0   1940-02-07   7.4
# 1         Fantasia         126.0  2280000.0   83300000.0   1940-11-13   7.8
# 2            Dumbo          64.0   950000.0    1300000.0   1941-10-23   7.2
# 3            Bambi          70.0   858000.0  267400000.0   1942-08-09   7.3
# 4  Make Mine Music          75.0  1350000.0    3275000.0   1946-04-20   6.3
#
#    metascore rotten_tomatoes  \
# 0       99.0            100%
# 1       96.0             95%
# 2       96.0             98%
# 3       91.0             90%
# 4       60.0             70%
#
#                                          Directed by  \
# 0  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 1  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 2  ['Supervising director:', 'Ben Sharpsteen', 'S...
# 3  ['Supervising director', 'David Hand', 'Sequen...
# 4  ['Jack Kinney', 'Clyde Geronimi', 'Hamilton Lu...
#
#                          Produced by  \
# 0                        Walt Disney
# 1  ['Walt Disney', 'Ben Sharpsteen']
# 2                        Walt Disney
# 3                        Walt Disney
# 4                        Walt Disney
#
#                                             Music by  \
# 0                 ['Leigh Harline', 'Paul J. Smith']
# 1                                        See program
# 2              ['Frank Churchill', 'Oliver Wallace']
# 3             ['Frank Churchill', 'Edward H. Plumb']
# 4  ['Eliot Daniel', 'Ken Darby', 'Charles Wolcott...
#
#                                       Distributed by  year
# 0                                 RKO Radio Pictures  1940
# 1  ['Walt Disney Productions', 'RKO Radio Pictures']  1940
# 2                                 RKO Radio Pictures  1941
# 3                                 RKO Radio Pictures  1942
# 4                           RKO Radio Pictures, Inc.  1946

# %%
# year range: [1940, 2020] 80 years
ax = data_final['year'].plot.hist(bins=80, figsize=(18,5))
ax.set_title("Yearly Released Movies")
# Out:
# Text(0.5, 1.0, 'Yearly Released Movies')

# %%
data_final.groupby(['year']).count()['title'].plot.bar(figsize=(18,5))
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# Start from year 1992, there is a increase of released Disney movie per year.

# %% [markdown]
# ## Ratings

# %%
# inspect the highest ratings by imdb
data_final.sort_values(by='imdb', ascending=0).head(5)
# Out:
#              title  Running time       Budget    Box office Release date  \
# 52   The Lion King          88.0   45000000.0  9.685000e+08   1994-06-15
# 219  The Lion King         118.0  250000000.0  1.657000e+09   2019-07-09
# 211           Coco         105.0  175000000.0  8.071000e+08   2017-10-20
# 144         WALL-E          97.0  180000000.0  5.333000e+08   2008-06-23
# 59       Toy Story          81.0   30000000.0  3.736000e+08   1995-11-19
#
#      imdb  metascore  rotten_tomatoes                      Directed by  \
# 52    8.5       88.0               93  ['Roger Allers', 'Rob Minkoff']
# 219   8.5       88.0               93                      Jon Favreau
# 211   8.4       81.0               97                      Lee Unkrich
# 144   8.4       95.0               95                   Andrew Stanton
# 59    8.3       95.0              100                    John Lasseter
#
#                                            Produced by           Music by  \
# 52                                            Don Hahn        Hans Zimmer
# 219  ['Jon Favreau', 'Jeffrey Silver', 'Karen Gilch...        Hans Zimmer
# 211                                  Darla K. Anderson  Michael Giacchino
# 144                                         Jim Morris      Thomas Newman
# 59               ['Bonnie Arnold', 'Ralph Guggenheim']       Randy Newman
#
#                                  Distributed by  year
# 52                         Buena Vista Pictures  1994
# 219  ['Walt Disney Studios', 'Motion Pictures']  2019
# 211  ['Walt Disney Studios', 'Motion Pictures']  2017
# 144         Walt Disney Studios Motion Pictures  2008
# 59            Buena Vista Pictures Distribution  1995

# %%
# inspect the highest ratings by metascore
data_final.sort_values(by='metascore', ascending=0).head()
# Out:
#            title  Running time       Budget   Box office Release date  imdb  \
# 0      Pinocchio          88.0    2600000.0  164000000.0   1940-02-07   7.4
# 2          Dumbo          64.0     950000.0    1300000.0   1941-10-23   7.2
# 135  Ratatouille         111.0  150000000.0  620700000.0   2007-06-22   8.0
# 217        Dumbo         112.0  170000000.0  353300000.0   2019-03-11   7.2
# 1       Fantasia         126.0    2280000.0   83300000.0   1940-11-13   7.8
#
#      metascore  rotten_tomatoes  \
# 0         99.0              100
# 2         96.0               98
# 135       96.0               96
# 217       96.0               98
# 1         96.0               95
#
#                                            Directed by  \
# 0    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 2    ['Supervising director:', 'Ben Sharpsteen', 'S...
# 135                                          Brad Bird
# 217                                         Tim Burton
# 1    ['Samuel Armstrong', 'James Algar', 'Bill Robe...
#
#                                            Produced by  \
# 0                                          Walt Disney
# 2                                          Walt Disney
# 135                                         Brad Lewis
# 217  ['Justin Springer', 'Ehren Kruger', 'Katterli ...
# 1                    ['Walt Disney', 'Ben Sharpsteen']
#
#                                   Music by  \
# 0       ['Leigh Harline', 'Paul J. Smith']
# 2    ['Frank Churchill', 'Oliver Wallace']
# 135                      Michael Giacchino
# 217                           Danny Elfman
# 1                              See program
#
#                                         Distributed by  year
# 0                                   RKO Radio Pictures  1940
# 2                                   RKO Radio Pictures  1941
# 135                  Buena Vista Pictures Distribution  2007
# 217         ['Walt Disney Studios', 'Motion Pictures']  2019
# 1    ['Walt Disney Productions', 'RKO Radio Pictures']  1940

# %%
# inspect the highest ratings by rotten_tomatoes
data_final.sort_values(by='rotten_tomatoes', ascending=0).head()
# Out:
#             title  Running time      Budget   Box office Release date  imdb  \
# 0       Pinocchio          88.0   2600000.0  164000000.0   1940-02-07   7.4
# 77    Toy Story 2          92.0  90000000.0  497400000.0   1999-11-13   7.9
# 124    Glory Road         106.0  30000000.0   42900000.0   2006-01-13   7.2
# 19   Mary Poppins         139.0   4400000.0  103100000.0   1964-08-27   7.8
# 59      Toy Story          81.0  30000000.0  373600000.0   1995-11-19   8.3
#
#      metascore  rotten_tomatoes  \
# 0         99.0              100
# 77        88.0              100
# 124       58.0              100
# 19        88.0              100
# 59        95.0              100
#
#                                            Directed by  \
# 0    ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 77                                       John Lasseter
# 124                                      James Gartner
# 19                                    Robert Stevenson
# 59                                       John Lasseter
#
#                                     Produced by  \
# 0                                   Walt Disney
# 77   ['Helene Plotkin', 'Karen Robert Jackson']
# 124                       ['Jerry Bruckheimer']
# 19                                  Walt Disney
# 59        ['Bonnie Arnold', 'Ralph Guggenheim']
#
#                                               Music by  \
# 0                   ['Leigh Harline', 'Paul J. Smith']
# 77                                        Randy Newman
# 124                                       Trevor Rabin
# 19   ['Richard M. Sherman (songs)', 'Robert B. Sher...
# 59                                        Randy Newman
#
#                         Distributed by  year
# 0                   RKO Radio Pictures  1940
# 77   Buena Vista Pictures Distribution  1999
# 124               Buena Vista Pictures  2006
# 19            Buena Vista Distribution  1964
# 59   Buena Vista Pictures Distribution  1995

# %%
ax = data_final['imdb'].plot.hist(bins=100, alpha=0.5)
ax.set_title("Ratings imdb Distribution")
# Out:
# Text(0.5, 1.0, 'Ratings imdb Distribution')

# %%
ax = data_final['metascore'].plot.hist(bins=100, alpha=0.5)
ax.set_title("Ratings metascore Distribution")
# Out:
# Text(0.5, 1.0, 'Ratings metascore Distribution')

# %%
# transfer percentage to number
data_final['rotten_tomatoes'] = data_final['rotten_tomatoes'].apply(lambda x: int(x[0:-1]))

# %%
ax = data_final['rotten_tomatoes'].plot.hist(bins=100, alpha=0.5)
ax.set_title("Ratings rotten_tomatoes Distribution")
ax.set_xlabel(" in %")
# Out:
# Text(0.5, 0, ' in %')

# %%
data_final.head()
# Out:
#              title  Running time     Budget   Box office Release date  imdb  \
# 0        Pinocchio          88.0  2600000.0  164000000.0   1940-02-07   7.4
# 1         Fantasia         126.0  2280000.0   83300000.0   1940-11-13   7.8
# 2            Dumbo          64.0   950000.0    1300000.0   1941-10-23   7.2
# 3            Bambi          70.0   858000.0  267400000.0   1942-08-09   7.3
# 4  Make Mine Music          75.0  1350000.0    3275000.0   1946-04-20   6.3
#
#    metascore  rotten_tomatoes  \
# 0       99.0              100
# 1       96.0               95
# 2       96.0               98
# 3       91.0               90
# 4       60.0               70
#
#                                          Directed by  \
# 0  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 1  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 2  ['Supervising director:', 'Ben Sharpsteen', 'S...
# 3  ['Supervising director', 'David Hand', 'Sequen...
# 4  ['Jack Kinney', 'Clyde Geronimi', 'Hamilton Lu...
#
#                          Produced by  \
# 0                        Walt Disney
# 1  ['Walt Disney', 'Ben Sharpsteen']
# 2                        Walt Disney
# 3                        Walt Disney
# 4                        Walt Disney
#
#                                             Music by  \
# 0                 ['Leigh Harline', 'Paul J. Smith']
# 1                                        See program
# 2              ['Frank Churchill', 'Oliver Wallace']
# 3             ['Frank Churchill', 'Edward H. Plumb']
# 4  ['Eliot Daniel', 'Ken Darby', 'Charles Wolcott...
#
#                                       Distributed by  year
# 0                                 RKO Radio Pictures  1940
# 1  ['Walt Disney Productions', 'RKO Radio Pictures']  1940
# 2                                 RKO Radio Pictures  1941
# 3                                 RKO Radio Pictures  1942
# 4                           RKO Radio Pictures, Inc.  1946

# %%
data_final.to_csv("full_data.csv")

# %% [markdown]
# ## About People (Director, Producer...)

# %%
data_final.head()
# Out:
#              title  Running time     Budget   Box office Release date  imdb  \
# 0        Pinocchio          88.0  2600000.0  164000000.0   1940-02-07   7.4
# 1         Fantasia         126.0  2280000.0   83300000.0   1940-11-13   7.8
# 2            Dumbo          64.0   950000.0    1300000.0   1941-10-23   7.2
# 3            Bambi          70.0   858000.0  267400000.0   1942-08-09   7.3
# 4  Make Mine Music          75.0  1350000.0    3275000.0   1946-04-20   6.3
#
#    metascore  rotten_tomatoes  \
# 0       99.0              100
# 1       96.0               95
# 2       96.0               98
# 3       91.0               90
# 4       60.0               70
#
#                                          Directed by  \
# 0  ['Ben Sharpsteen', 'Hamilton Luske', 'Bill Rob...
# 1  ['Samuel Armstrong', 'James Algar', 'Bill Robe...
# 2  ['Supervising director:', 'Ben Sharpsteen', 'S...
# 3  ['Supervising director', 'David Hand', 'Sequen...
# 4  ['Jack Kinney', 'Clyde Geronimi', 'Hamilton Lu...
#
#                          Produced by  \
# 0                        Walt Disney
# 1  ['Walt Disney', 'Ben Sharpsteen']
# 2                        Walt Disney
# 3                        Walt Disney
# 4                        Walt Disney
#
#                                             Music by  \
# 0                 ['Leigh Harline', 'Paul J. Smith']
# 1                                        See program
# 2              ['Frank Churchill', 'Oliver Wallace']
# 3             ['Frank Churchill', 'Edward H. Plumb']
# 4  ['Eliot Daniel', 'Ken Darby', 'Charles Wolcott...
#
#                                       Distributed by  year
# 0                                 RKO Radio Pictures  1940
# 1  ['Walt Disney Productions', 'RKO Radio Pictures']  1940
# 2                                 RKO Radio Pictures  1941
# 3                                 RKO Radio Pictures  1942
# 4                           RKO Radio Pictures, Inc.  1946

# %%
def get_name_count(string, dic):
    if(string == 'nan'):
        return dic
    # if the string is with []
    #print(string)
    if('[' in string):
        # get rid of the []
        string = string[1:-1]
        
    names = string.split(', ')
    for name in names:
        # if name string with ''
        if('\'' in name):
            name = name[1:-1]
        if name in dic:
            dic[name] += 1
        else:
            dic[name] = 1
            
    return dic

# %%
directors = {}
producers = {}
music_by = {}
distributed_by = {}

for ind, row in data_final.iterrows():
    if(pd.notna(row['Directed by'])):
        directors = get_name_count(row['Directed by'],directors)
    if(pd.notna(row['Produced by'])):
        producers = get_name_count(row['Produced by'],producers)
    if(pd.notna(row['Music by'])):
        music_by = get_name_count(row['Music by'],music_by)
    if(pd.notna(row['Distributed by'])):
        distributed_by = get_name_count(row['Distributed by'],distributed_by)

# %%
directors = {k: v for k, v in sorted(directors.items(), key=lambda item: item[1])}
producers = {k: v for k, v in sorted(producers.items(), key=lambda item: item[1])}
music_by = {k: v for k, v in sorted(music_by.items(), key=lambda item: item[1])}
distributed_by = {k: v for k, v in sorted(distributed_by.items(), key=lambda item: item[1])}

# %%
directors
# Out:
# {'David D. Hand': 1,
#  'Jim Handley': 1,
#  'Ford Beebe': 1,
#  'Supervising director:': 1,
#  'Sequence directors:': 1,
#  'Supervising director': 1,
#  'David Hand': 1,
#  'Sequence directors': 1,
#  'Graham Heid': 1,
#  'Norman Wright': 1,
#  'Joshua Meador': 1,
#  'Robert Cormack': 1,
#  'Live action:': 1,
#  'Harve Foster': 1,
#  'Animation:': 1,
#  'Richard Fleischer': 1,
#  'Clyde Geronimi (supervising)': 1,
#  'Eric Larson': 1,
#  'Les Clark': 1,
#  'Charles Barton': 1,
#  'John McKimson': 1,
#  'Ken Annakin': 1,
#  'Jack Donohue': 1,
#  'John Lounsbery': 1,
#  'Don Chaffey': 1,
#  'Robert Altman': 1,
#  'Matthew Robbins': 1,
#  'Tim Hunter': 1,
#  'Walter Murch': 1,
#  'Burny Mattinson': 1,
#  'Dave Michener': 1,
#  'George Scribner': 1,
#  'Kenny Ortega': 1,
#  'Rupert Wainwright': 1,
#  'Roger Allers': 1,
#  'William Dear': 1,
#  'James Orr': 1,
#  'Mike Gabriel': 1,
#  'Simon Wincer': 1,
#  'Michael Gottlieb': 1,
#  'David M. Evans': 1,
#  'Sam Weisman': 1,
#  'Les Mayfield': 1,
#  'Stanley Tong': 1,
#  'Barry Cook': 1,
#  'Tony Bancroft': 1,
#  'Nancy Meyers': 1,
#  'Ron Underwood': 1,
#  'Donald Petrie': 1,
#  'David Kellogg': 1,
#  'Jun Falkenstein': 1,
#  'Ralph Zondag': 1,
#  'Eric Leighton': 1,
#  'Boaz Yakin': 1,
#  'Chuck Sheetz': 1,
#  'Tim Hill': 1,
#  'Brian Levant': 1,
#  'Robin Budd': 1,
#  'Chris Sanders': 1,
#  'Dean DeBlois': 1,
#  'Peter Hastings': 1,
#  'Jay Russell': 1,
#  'Steve Trenbirth': 1,
#  'James Cameron': 1,
#  'Andrew Davis': 1,
#  'Jim Fall': 1,
#  'Mark Waters': 1,
#  'Aaron Blaise': 1,
#  'Robert Walker': 1,
#  "avin O'Conno": 1,
#  'Sara Sugarman': 1,
#  'Will Finn': 1,
#  'John Sanford': 1,
#  'Frank Coraci': 1,
#  'Luc Jacquet': 1,
#  'Frank Nissen': 1,
#  'Tim Fywell': 1,
#  'Gary Chapman': 1,
#  'Angela Robinson': 1,
#  'Mike Mitchell': 1,
#  'Bill Paxton': 1,
#  'James Gartner': 1,
#  'George Butler': 1,
#  'Frank Marshall': 1,
#  'Brian Robbins': 1,
#  'Steve "Spaz" Williams': 1,
#  'Ericson Core': 1,
#  'Gábor Csupó': 1,
#  'Frederik Du Chau': 1,
#  'Bruce Hendricks': 1,
#  'Roger Kumble': 1,
#  'Peter Chelsom': 1,
#  'Hoyt H. Yeatman Jr.': 1,
#  'Jacques Perrin': 1,
#  'Jacques Cluzaud': 1,
#  '(co-director)': 1,
#  'Robert Zemeckis': 1,
#  'Walt Becker': 1,
#  'Mike Newell': 1,
#  'Hiromasa Yonebayashi': 1,
#  'Randall Wallace': 1,
#  'Nathan Greno': 1,
#  'Joseph Kosinski': 1,
#  'Simon Wells': 1,
#  'Stephen J. Anderson': 1,
#  'Joe Nussbaum': 1,
#  'Mark Andrews': 1,
#  'Brenda Chapman': 1,
#  'Peter Hedges': 1,
#  'Sam Raimi': 1,
#  'Klay Hall': 1,
#  'Robert Stromberg': 1,
#  'Bobs Gannaway': 1,
#  'Miguel Arteta': 1,
#  'Kenneth Branagh': 1,
#  'Peter Sohn': 1,
#  'Steven Spielberg': 1,
#  'David Lowery': 1,
#  'Lu Chuan': 1,
#  'Mira Nair': 1,
#  'Bill Condon': 1,
#  'Espen Sandberg': 1,
#  'Brian Fee': 1,
#  'Ava DuVernay': 1,
#  'Lasse Hallström': 1,
#  'Phil Johnston': 1,
#  'Josh Cooley': 1,
#  'T. Hee': 2,
#  'Paul Satterfield': 2,
#  'Art Stevens': 2,
#  'Ted Berman': 2,
#  'Richard Rich': 2,
#  'Brian Henson': 2,
#  'Henry Selick': 2,
#  'Rob Minkoff': 2,
#  'John Pasquin': 2,
#  'Don Hahn': 2,
#  'Pixote Hunt': 2,
#  'Hendel Butoy': 2,
#  'Paul and Gaëtan Brizzi': 2,
#  'Mark Dindal': 2,
#  'Garry Marshall': 2,
#  'John Lee Hancock': 2,
#  'Michael Lembeck': 2,
#  'Adam Shankman': 2,
#  'Andrew Adamson': 2,
#  'Andy Fickman': 2,
#  'Raja Gosnell': 2,
#  'Chris Williams': 2,
#  'Lee Unkrich': 2,
#  'Don Hall': 2,
#  'Keith Scholey': 2,
#  'Dan Scanlon': 2,
#  'Jennifer Lee': 2,
#  'Craig Gillespie': 2,
#  'Niki Caro': 2,
#  'Jon Favreau': 2,
#  'Joachim Rønning': 2,
#  'Ben Sharpsteen': 3,
#  'Norman Ferguson': 3,
#  'Samuel Armstrong': 3,
#  'Robert Stevenson': 3,
#  'Gary Nelson': 3,
#  'Randal Kleiser': 3,
#  'Joe Johnston': 3,
#  'Gary Trousdale': 3,
#  'Kirk Wise': 3,
#  'Stephen Herek': 3,
#  'Eric Goldberg': 3,
#  'Kevin Lima': 3,
#  'Chris Buck': 3,
#  'Francis Glebas': 3,
#  'Pete Docter': 3,
#  'Brad Bird': 3,
#  'Mark Linfield': 3,
#  'Byron Howard': 3,
#  'Tim Burton': 3,
#  'Rob Marshall': 3,
#  'James Bobin': 3,
#  'Rich Moore': 3,
#  'Bill Roberts': 4,
#  'Jack Kinney': 4,
#  'Jon Turteltaub': 4,
#  'Andrew Stanton': 4,
#  'Gore Verbinski': 4,
#  'James Algar': 5,
#  'John Lasseter': 5,
#  'Alastair Fothergill': 5,
#  'Ron Clements': 6,
#  'John Musker': 6,
#  'Clyde Geronimi': 7,
#  'Wolfgang Reitherman': 7,
#  'Hamilton Luske': 9,
#  'Wilfred Jackson': 9}

# %%
fig, ax = plt.subplots(figsize=(18, 5))
ax.bar(range(len(directors)), list(directors.values()))
plt.xticks(range(len(directors)), list(directors.keys()), rotation=90)
plt.show()

# %% [markdown]
# Hamilton Luske and Wilfred Jackson are the directors of with the most disney movies, which is 9respectively.

# %%
producers
# Out:
# {'Bill Anderson': 1,
#  'Basil Keys': 1,
#  'Winston Hibler': 1,
#  'Jerome Courtland': 1,
#  'Robert Evans': 1,
#  'Hal Barwood': 1,
#  'Howard W. Koch': 1,
#  'Art Stevens': 1,
#  'Tim Zinnemann': 1,
#  'Paul Maslansky': 1,
#  'Joe Hale': 1,
#  'Burny Mattinson': 1,
#  'Dimitri Villard': 1,
#  'Robert Wald': 1,
#  'Penney Finkelman Cox': 1,
#  'Markay Powell': 1,
#  'Charles Gordon': 1,
#  'Lawrence Gordon': 1,
#  'Lloyd Levin': 1,
#  'Michael Finnell': 1,
#  'Susan B. Landau': 1,
#  'Jeffrey Bydalek': 1,
#  'Gary Adelson': 1,
#  'Craig Baumgarten': 1,
#  'Tony Shimkin': 1,
#  'Irby Smith': 1,
#  'Bonnie Bruckheimer': 1,
#  'Marty Katz': 1,
#  'Jim Pentecost': 1,
#  'Diane Nabatoff': 1,
#  'David Madden': 1,
#  'J.P. Guerin': 1,
#  'Ralph Guggenheim': 1,
#  'Richard Baker': 1,
#  'Brad Krevoy': 1,
#  'Alice Dewey': 1,
#  'Ben Myron': 1,
#  'Pam Coats': 1,
#  'Charles Shyer': 1,
#  'Ted Hartley': 1,
#  'Tom Jacobson': 1,
#  'Marc Toberoff': 1,
#  'Andy Heyward': 1,
#  'Aaron Meyerson': 1,
#  'Helene Plotkin': 1,
#  'Karen Robert Jackson': 1,
#  'Roy E. Disney': 1,
#  'Cheryl Abood': 1,
#  'Pam Marsden': 1,
#  'Chad Oman': 1,
#  'Joe Ansolabehere': 1,
#  'Paul Germain': 1,
#  'Stephen Swofford': 1,
#  'Mario Iscovich': 1,
#  'Mike Karz': 1,
#  'Dan Rounds': 1,
#  'Marc Abraham': 1,
#  'Jane Startz': 1,
#  'Thomas Bliss': 1,
#  'Mary Thorne': 1,
#  'John Bruno': 1,
#  'James Cameron': 1,
#  'Chuck Comisky': 1,
#  'Janace Tashjian': 1,
#  'Andrew Wight': 1,
#  'Andrew Davis': 1,
#  'Lowell D. Blank': 1,
#  'Mike Medavoy': 1,
#  'Teresa Tucker-Davies': 1,
#  'Stan Rogow': 1,
#  'Graham Walters': 1,
#  'Chuck Williams': 1,
#  'Ross Greenburg': 1,
#  'Justis Greene': 1,
#  'Jon Mone': 1,
#  "Greg O'Connor": 1,
#  'Alice Dewey Goldstone': 1,
#  'Bill Badalato': 1,
#  'Yves Darondeau': 1,
#  'Christophe Lioud': 1,
#  'Emmanuel Priou': 1,
#  'Jessica Koplos-Miller': 1,
#  'Bridget Johnson': 1,
#  'John H. Williams': 1,
#  'Barnaby Thompson (executive producer)': 1,
#  'Robert Simonds': 1,
#  'Larry Brezner': 1,
#  'Mark Frost': 1,
#  'Phillip Steuer': 1,
#  'George Butler': 1,
#  'Patrick Crowley': 1,
#  'Tim Allen': 1,
#  'Clint Goldman': 1,
#  'Beau Flynn': 1,
#  'David L. Paterson': 1,
#  'Lauren Levine': 1,
#  'Brad Lewis': 1,
#  'Jay Polstein': 1,
#  'Sophokles Tasioulius': 1,
#  'Barry Josephson': 1,
#  'Barry Sonnenfeld': 1,
#  'Art Repola': 1,
#  'Andrew Adamson': 1,
#  'Adam Sandler': 1,
#  'Jack Giarraputo': 1,
#  'Billy Ray Cyrus': 1,
#  'Alfred Gough': 1,
#  'Miles Millar': 1,
#  'Steven Peterman': 1,
#  'Michael Poryes': 1,
#  'Jacques Perrin': 1,
#  'Romain Legrand': 1,
#  'Nicolas Mauvernay': 1,
#  'Jake Eberts': 1,
#  'Andrew Panay': 1,
#  'Richard D. Zanuck': 1,
#  'Toshio Suzuki': 1,
#  'Sean Bailey': 1,
#  'Steven Lisberger': 1,
#  'Steven Boyd': 1,
#  'Keith Scholey': 1,
#  'Ted Griffin': 1,
#  'Jerry Bruckheimer ': 1,
#  'Neal H. Moritz': 1,
#  'Colin Wilson': 1,
#  'Katherine Sarafian': 1,
#  'Scott Sanders': 1,
#  'Ahmet Zappa': 1,
#  'Allison Abbate': 1,
#  'Gore Verbinski': 1,
#  'Tracy Balthazor-Flynn': 1,
#  'Alison Owen': 1,
#  'Ian Collie': 1,
#  'Ferrell Barron': 1,
#  'Shawn Levy': 1,
#  'Dan Levine': 1,
#  'Lisa Henson': 1,
#  'Callum McDougall': 1,
#  'Simon Kinberg': 1,
#  'Allison Shearmur': 1,
#  'David Barron': 1,
#  'Damon Lindelof': 1,
#  'Brad Bird': 1,
#  'Dorothy Aufiero': 1,
#  'Brigham Taylor': 1,
#  'Steven Spielberg': 1,
#  'Sam Mercer': 1,
#  'Brian Leith': 1,
#  'Phil Chapman': 1,
#  'John Carls': 1,
#  'Lydia Dean Pilcher': 1,
#  'Osnat Shurer': 1,
#  'Catherine Hand': 1,
#  'John Walker': 1,
#  'Nicole Paradis Grindle': 1,
#  'Mark Gordon': 1,
#  'Larry Franco': 1,
#  'Ehren Kruger': 1,
#  'Katterli Frauenfelder': 1,
#  'Derek Frey': 1,
#  'Mark Nielsen': 1,
#  'Karen Gilchrist': 1,
#  'Angelina Jolie': 1,
#  'Duncan Henderson': 1,
#  'Chris Bender': 1,
#  'Jake Weiner': 1,
#  'Jason T. Reed': 1,
#  'Ben Sharpsteen': 2,
#  'Ron W. Miller': 2,
#  'Dawn Steel': 2,
#  'Edward S. Feldman': 2,
#  'Brian Henson': 2,
#  'Martin G. Baker': 2,
#  'Denise Di Novi': 2,
#  'Peter Abrams': 2,
#  'Robert L. Levy': 2,
#  'Bonnie Arnold': 2,
#  'John Hughes': 2,
#  'Ricardo Mestres': 2,
#  'Kevin Reher': 2,
#  'Jerry Leider': 2,
#  'Robert Shapiro': 2,
#  'Donald W. Ernst': 2,
#  'Randy Fullmer': 2,
#  'Whitney Houston': 2,
#  'Debra Martin Chase': 2,
#  'Christopher Chase': 2,
#  'Michelle Pappalardo-Robinson': 2,
#  'Jeffrey Chernov': 2,
#  'Hal Lieberman': 2,
#  'Jon Turteltaub': 2,
#  'Gary Barber': 2,
#  'Jonathan Glickman': 2,
#  'David Blocker': 2,
#  'Frank Marshall': 2,
#  'Philip Steuer': 2,
#  'Jim Morris': 2,
#  'John Jacobs': 2,
#  'Ricardo Del Río': 2,
#  'Steve Starkey': 2,
#  'Robert Zemeckis': 2,
#  'Jack Rapke': 2,
#  'Suzanne Todd': 2,
#  'Jennifer Todd': 2,
#  'Justin Springer': 2,
#  'Denise Ream': 2,
#  'Lindsey Collins': 2,
#  'Alastair Fothergill': 2,
#  'Mark Linfield': 2,
#  'James Whitaker': 2,
#  'Kori Rae': 2,
#  'Rob Marshall': 2,
#  'John DeLuca': 2,
#  'Marc Platt': 2,
#  'Jim Whitaker': 2,
#  'Jon Favreau': 2,
#  'Bill Walsh': 3,
#  'Jon Avnet': 3,
#  'John Musker': 3,
#  'Ron Clements': 3,
#  'Robert Newmyer': 3,
#  'Brian Reilly': 3,
#  'Mark Johnson': 3,
#  'Alix Tidmarsh': 3,
#  'Jonas Rivera': 3,
#  'Wolfgang Reitherman': 4,
#  'Jordan Kerner': 4,
#  'Tim Burton': 4,
#  'Roy Conli': 4,
#  'Peter Del Vecho': 4,
#  'Don Hahn': 5,
#  'Jeffrey Silver': 5,
#  'Darla K. Anderson': 5,
#  'Todd Lieberman': 5,
#  'Ron Miller': 6,
#  'Roger Birnbaum': 6,
#  'Clark Spencer': 6,
#  'Mark Ciardi': 7,
#  'Gordon Gray': 7,
#  'Andrew Gunn': 7,
#  'Joe Roth': 8,
#  'David Hoberman': 8,
#  'Jerry Bruckheimer': 12,
#  'Walt Disney': 21}

# %%
fig, ax = plt.subplots(figsize=(18, 5))
ax.bar(range(len(producers)), list(producers.values()))
plt.xticks(range(len(producers)), list(producers.keys()), rotation=90)
plt.show()

# %% [markdown]
# Most disney movies (21) are produced by Walt Disney.

# %%
music_by
# Out:
# {'Leigh Harline': 1,
#  'Edward H. Plumb': 1,
#  'Daniele Amfitheatrof': 1,
#  'Paul Smith': 1,
#  'Joseph S. Dubin': 1,
#  '(orchestration)': 1,
#  "eorge Bruns (adapted from Tchaikovsky's Sleeping Beauty Ballet ": 1,
#  'William Alwyn': 1,
#  '(composer)': 1,
#  'Muir Mathieson': 1,
#  '(conductor)': 1,
#  'Victor Herbert': 1,
#  'Mel Leven (new lyrics)': 1,
#  'Richard M. Sherman (songs)': 1,
#  'Robert B. Sherman (songs)': 1,
#  'Irwin Kostal (score)': 1,
#  'Artie Butler': 1,
#  'John Barry': 1,
#  'Harry Nilsson': 1,
#  'Alex North': 1,
#  'Buddy Baker': 1,
#  'Pino Donaggio': 1,
#  'David Shire': 1,
#  'Elmer Bernstein': 1,
#  'Henry Mancini': 1,
#  'Basil Poledouris': 1,
#  '(additional music)': 1,
#  'Bruce Broughton': 1,
#  'Miles Goodman': 1,
#  'Nicholas Pike': 1,
#  'Richard Gibbs': 1,
#  'Mike Tavera': 1,
#  'Jerry Goldsmith': 1,
#  'Denis M. Hannigan': 1,
#  'Michael Wandmacher': 1,
#  'Joel McNeely (Score)': 1,
#  'They Might Be Giants (Songs)': 1,
#  'Christopher Young': 1,
#  'William Ross': 1,
#  'Carl Johnson': 1,
#  'Carly Simon': 1,
#  'Cliff Eidelman': 1,
#  'Klaus Badelt': 1,
#  'Rolfe Kent': 1,
#  'Phil Collins': 1,
#  'Trevor Jones': 1,
#  'David A. Stewart': 1,
#  'Émilie Simon (France)': 1,
#  'Alex Wurman (US)': 1,
#  'Brian Tyler': 1,
#  'Philip Glass': 1,
#  'Sigur Rós': 1,
#  'Aaron Zigman': 1,
#  'Nathan Wang': 1,
#  'Berliner Philharmoniker': 1,
#  'Matthew Gerrard': 1,
#  'Robbie Nevil': 1,
#  'Miley Cyrus': 1,
#  'Jamie Houston': 1,
#  'Tim James': 1,
#  'Edward Shearmur': 1,
#  'Rupert Gregson-Williams': 1,
#  'Bruno Coulais': 1,
#  'Cécile Corbel': 1,
#  'Nick Glennie-Smith': 1,
#  'Daft Punk': 1,
#  'Deborah Lurie': 1,
#  'A. R. Rahman': 1,
#  'Stephen Sondheim': 1,
#  'Antônio Pinto': 1,
#  'John Williams': 1,
#  'Daniel Hart': 1,
#  'Barnaby Taylor': 1,
#  'Alex Heffes': 1,
#  'Lin-Manuel Miranda': 1,
#  "Opetaia Foa'i": 1,
#  'Ramin Djawadi': 1,
#  'Frank Churchill': 2,
#  'Eliot Daniel': 2,
#  'Ken Darby': 2,
#  'Charles Wolcott': 2,
#  'Edward Plumb': 2,
#  'Irwin Kostal': 2,
#  'Johnny Mandel': 2,
#  'Michael Kamen': 2,
#  'Randy Edelman': 2,
#  'Michael Convertino': 2,
#  'Marc Shaiman': 2,
#  'Carter Burwell': 2,
#  'George S. Clinton': 2,
#  'Mark Mothersbaugh': 2,
#  'Heitor Pereira': 2,
#  'John Powell': 2,
#  'Nicholas Hooper': 2,
#  'Patrick Doyle': 2,
#  'Robert Lopez': 2,
#  'Kristen Anderson-Lopez': 2,
#  'Mychael Danna': 2,
#  'Jeff Danna': 2,
#  'See program': 3,
#  'J. A. C. Redford': 3,
#  'James Horner': 3,
#  'David Newman': 3,
#  'Mark Isham': 3,
#  'George Fenton': 3,
#  'Geoff Zanelli': 3,
#  'Joel McNeely': 4,
#  'Thomas Newman': 4,
#  'Henry Jackman': 4,
#  'Alan Silvestri': 5,
#  'James Newton Howard': 5,
#  'Paul J. Smith': 6,
#  'Oliver Wallace': 6,
#  'Harry Gregson-Williams': 6,
#  'Christophe Beck': 6,
#  'George Bruns': 7,
#  'Danny Elfman': 7,
#  'Mark Mancina': 7,
#  'Trevor Rabin': 7,
#  'Hans Zimmer': 9,
#  'Michael Giacchino': 10,
#  'Alan Menken': 11,
#  'Randy Newman': 11,
#  'John Debney': 11}

# %%
fig, ax = plt.subplots(figsize=(18, 5))
ax.bar(range(len(music_by)), list(music_by.values()))
plt.xticks(range(len(music_by)), list(music_by.keys()), rotation=90)
plt.show()

# %% [markdown]
# John Debney, Alan Menken, Randy Newman make music for most (11) disney movies.

# %%
distributed_by
# Out:
# {'Walt Disney Productions': 1,
#  'Buena Vista Film Distribution': 1,
#  'Paramount Pictures (North America)': 1,
#  '(North America)': 1,
#  'Buena Vista International Distribution (International)': 1,
#  'Paramount Pictures': 1,
#  'Buena Vista International Distribution': 1,
#  'PSO Productions (outside North America)': 1,
#  'Trimark Pictures (International)': 1,
#  '(Global)': 1,
#  'Guild Film Distribution': 1,
#  '(United Kingdom)': 1,
#  'Ariane Films': 1,
#  '(France)': 1,
#  'Buena Vista International France': 1,
#  'Entertainment Film Distributors (UK)': 1,
#  'Buena Vista Pictures (US)': 1,
#  'Summit Entertainment': 1,
#  'Gaumount (France)': 1,
#  'Lionsgate UK (United Kingdom)': 1,
#  'Universum Film (Germany)': 1,
#  'Walt Disney Studios Motion Pictures (United States)': 1,
#  'Pathé Distribution': 1,
#  'Toho': 1,
#  '(Worldwide)': 1,
#  'Mister Smith Entertainment': 1,
#  '(': 1,
#  'EMEA': 1,
#  ')': 1,
#  'Shanghai Media Group': 1,
#  '(China)': 1,
#  'Inc.': 2,
#  '(International)': 2,
#  '(United States)': 3,
#  'RKO Radio Pictures': 10,
#  'Buena Vista Pictures Distribution': 21,
#  'Walt Disney Studios Motion Pictures': 23,
#  'Buena Vista Distribution': 24,
#  'Walt Disney Studios': 60,
#  'Motion Pictures': 60,
#  'Buena Vista Pictures': 78}

# %%
fig, ax = plt.subplots(figsize=(18, 5))
ax.bar(range(len(distributed_by)), list(distributed_by.values()))
plt.xticks(range(len(distributed_by)), list(distributed_by.keys()), rotation=90)
plt.show()

# %% [markdown]
# Most of the disney movies are distributed by Buena Vista Pictures.
